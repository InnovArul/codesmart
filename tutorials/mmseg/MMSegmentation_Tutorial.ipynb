# %% [markdown]
# # MMSegmentation Tutorial
# Welcome to MMSegmentation!
#
# In this tutorial, we demo
# * How to do inference with MMSeg trained weight
# * How to train on your own dataset and visualize the results.

# %% [markdown]
# ## Install MMSegmentation
# This step may take several minutes.
#
# We use PyTorch 1.12 and CUDA 11.3 for this tutorial. You may install other versions by change the version number in pip install command.

# %%
# Reset PATH to a common Colab default
# %env PATH=/usr/local/nvidia/bin:/usr/local/cuda/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/tools/node/bin:/tools/google-cloud-sdk/bin

print("PATH environment variable reset to default.")
# !echo $PATH
# Out:
# env: PATH=/usr/local/nvidia/bin:/usr/local/cuda/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/tools/node/bin:/tools/google-cloud-sdk/bin
# PATH environment variable reset to default.
# /usr/local/nvidia/bin:/usr/local/cuda/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/tools/node/bin:/tools/google-cloud-sdk/bin

# %%
import os

# Install miniforge
# !wget https://github.com/conda-forge/miniforge/releases/latest/download/Miniforge3-Linux-x86_64.sh
# !bash Miniforge3-Linux-x86_64.sh -b -p /home/miniforge3
# Out:
# --2025-12-25 19:55:08--  https://github.com/conda-forge/miniforge/releases/latest/download/Miniforge3-Linux-x86_64.sh
# Resolving github.com (github.com)... 140.82.112.3
# Connecting to github.com (github.com)|140.82.112.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://github.com/conda-forge/miniforge/releases/download/25.11.0-1/Miniforge3-Linux-x86_64.sh [following]
# --2025-12-25 19:55:08--  https://github.com/conda-forge/miniforge/releases/download/25.11.0-1/Miniforge3-Linux-x86_64.sh
# Reusing existing connection to github.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://release-assets.githubusercontent.com/github-production-release-asset/221584272/88c3b2ae-9e3f-448e-80be-e7a0cf00c0c1?sp=r&sv=2018-11-09&sr=b&spr=https&se=2025-12-25T20%3A30%3A47Z&rscd=attachment%3B+filename%3DMiniforge3-Linux-x86_64.sh&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2025-12-25T19%3A30%3A41Z&ske=2025-12-25T20%3A30%3A47Z&sks=b&skv=2018-11-09&sig=KaFC5i4vBoWk7la3EsToJ9ZjQ%2F2AYugKJe8FDUrBgqQ%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc2NjY5NDMwOCwibmJmIjoxNzY2NjkyNTA4LCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.MRQXdUrwST0Hhc3k_dlkXlZ8lfmA4bv8gOnfeOUMl98&response-content-disposition=attachment%3B%20filename%3DMiniforge3-Linux-x86_64.sh&response-content-type=application%2Foctet-stream [following]
# --2025-12-25 19:55:08--  https://release-assets.githubusercontent.com/github-production-release-asset/221584272/88c3b2ae-9e3f-448e-80be-e7a0cf00c0c1?sp=r&sv=2018-11-09&sr=b&spr=https&se=2025-12-25T20%3A30%3A47Z&rscd=attachment%3B+filename%3DMiniforge3-Linux-x86_64.sh&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2025-12-25T19%3A30%3A41Z&ske=2025-12-25T20%3A30%3A47Z&sks=b&skv=2018-11-09&sig=KaFC5i4vBoWk7la3EsToJ9ZjQ%2F2AYugKJe8FDUrBgqQ%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc2NjY5NDMwOCwibmJmIjoxNzY2NjkyNTA4LCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.MRQXdUrwST0Hhc3k_dlkXlZ8lfmA4bv8gOnfeOUMl98&response-content-disposition=attachment%3B%20filename%3DMiniforge3-Linux-x86_64.sh&response-content-type=application%2Foctet-stream
# Resolving release-assets.githubusercontent.com (release-assets.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to release-assets.githubusercontent.com (release-assets.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 85771392 (82M) [application/octet-stream]
# Saving to: ‘Miniforge3-Linux-x86_64.sh’
#
# Miniforge3-Linux-x8 100%[===================>]  81.80M   367MB/s    in 0.2s
#
# 2025-12-25 19:55:08 (367 MB/s) - ‘Miniforge3-Linux-x86_64.sh’ saved [85771392/85771392]
#
# PREFIX=/home/miniforge3
# Unpacking bootstrapper...
# Unpacking payload...
# Extracting _libgcc_mutex-0.1-conda_forge.tar.bz2
# Extracting ca-certificates-2025.11.12-hbd8a1cb_0.conda
# Extracting libgomp-15.2.0-he0feb66_15.conda
# Extracting nlohmann_json-abi-3.12.0-h0f90c79_1.conda
# Extracting pybind11-abi-11-hc364b38_1.conda
# Extracting python_abi-3.12-8_cp312.conda
# Extracting tzdata-2025b-h78e105d_0.conda
# Extracting _openmp_mutex-4.5-2_gnu.tar.bz2
# Extracting libgcc-15.2.0-he0feb66_15.conda
# Extracting bzip2-1.0.8-hda65f42_8.conda
# Extracting c-ares-1.34.5-hb9d3cd8_0.conda
# Extracting keyutils-1.6.3-hb9d3cd8_0.conda
# Extracting libexpat-2.7.3-hecca717_0.conda
# Extracting libffi-3.5.2-h9ec8514_0.conda
# Extracting libgcc-ng-15.2.0-h69a702a_15.conda
# Extracting libiconv-1.18-h3b78370_2.conda
# Extracting liblzma-5.8.1-hb9d3cd8_2.conda
# Extracting libnsl-2.0.1-hb9d3cd8_1.conda
# Extracting libstdcxx-15.2.0-h934c35e_15.conda
# Extracting libuuid-2.41.2-h5347b49_1.conda
# Extracting libzlib-1.3.1-hb9d3cd8_2.conda
# Extracting lzo-2.10-h280c20c_1002.conda
# Extracting ncurses-6.5-h2d0b736_3.conda
# Extracting openssl-3.6.0-h26f9b46_0.conda
# Extracting reproc-14.2.5.post0-hb9d3cd8_0.conda
# Extracting cpp-expected-1.3.1-h171cf75_0.conda
# Extracting fmt-12.0.0-h2b0788b_0.conda
# Extracting libedit-3.1.20250104-pl5321h7949ede_0.conda
# Extracting libev-4.33-hd590300_2.conda
# Extracting libsolv-0.7.35-h9463b59_0.conda
# Extracting libsqlite-3.51.1-h0c1763c_0.conda
# Extracting libssh2-1.11.1-hcf80075_0.conda
# Extracting libstdcxx-ng-15.2.0-hdf11a46_15.conda
# Extracting libxcrypt-4.4.36-hd590300_1.conda
# Extracting libxml2-16-2.15.1-hf2a90c1_0.conda
# Extracting lz4-c-1.10.0-h5888daf_1.conda
# Extracting readline-8.2-h8c095d6_2.conda
# Extracting reproc-cpp-14.2.5.post0-h5888daf_0.conda
# Extracting simdjson-4.2.2-hb700be7_0.conda
# Extracting tk-8.6.13-noxft_ha0e22de_103.conda
# Extracting yaml-cpp-0.8.0-h3f2d84a_0.conda
# Extracting zstd-1.5.7-hb78ec9c_6.conda
# Extracting krb5-1.21.3-h659f571_0.conda
# Extracting ld_impl_linux-64-2.45-default_hbd61a6d_104.conda
# Extracting libnghttp2-1.67.0-had1ee68_0.conda
# Extracting libxml2-2.15.1-h031cc0b_0.conda
# Extracting libarchive-3.8.2-gpl_h7be2006_100.conda
# Extracting libcurl-8.17.0-h4e3cde8_0.conda
# Extracting python-3.12.12-hd63d673_1_cpython.conda
# Extracting libmamba-2.4.0-hed7d790_1.conda
# Extracting menuinst-2.4.1-py312h7900ff3_0.conda
# Extracting archspec-0.2.5-pyhd8ed1ab_0.conda
# Extracting boltons-25.0.0-pyhd8ed1ab_0.conda
# Extracting brotli-python-1.2.0-py312hdb49522_1.conda
# Extracting certifi-2025.11.12-pyhd8ed1ab_0.conda
# Extracting charset-normalizer-3.4.4-pyhd8ed1ab_0.conda
# Extracting colorama-0.4.6-pyhd8ed1ab_1.conda
# Extracting distro-1.9.0-pyhd8ed1ab_1.conda
# Extracting frozendict-2.4.7-py312h4c3975b_0.conda
# Extracting hpack-4.1.0-pyhd8ed1ab_0.conda
# Extracting hyperframe-6.1.0-pyhd8ed1ab_0.conda
# Extracting idna-3.11-pyhd8ed1ab_0.conda
# Extracting jsonpointer-3.0.0-py312h7900ff3_2.conda
# Extracting libmambapy-2.4.0-py312h17091a9_1.conda
# Extracting mamba-2.4.0-h7ae174a_1.conda
# Extracting msgpack-python-1.1.2-py312hd9148b4_1.conda
# Extracting packaging-25.0-pyh29332c3_1.conda
# Extracting platformdirs-4.5.0-pyhcf101f3_0.conda
# Extracting pluggy-1.6.0-pyhf9edf01_1.conda
# Extracting pycosat-0.6.6-py312h4c3975b_3.conda
# Extracting pycparser-2.22-pyh29332c3_1.conda
# Extracting pysocks-1.7.1-pyha55dd90_7.conda
# Extracting ruamel.yaml.clib-0.2.14-py312h4c3975b_0.conda
# Extracting setuptools-80.9.0-pyhff2d567_0.conda
# Extracting truststore-0.10.3-pyhe01879c_0.conda
# Extracting wheel-0.45.1-pyhd8ed1ab_1.conda
# Extracting cffi-2.0.0-py312h460c074_1.conda
# Extracting h2-4.3.0-pyhcf101f3_0.conda
# Extracting jsonpatch-1.33-pyhd8ed1ab_1.conda
# Extracting pip-25.3-pyh8b19718_0.conda
# Extracting ruamel.yaml-0.18.16-py312h4c3975b_0.conda
# Extracting tqdm-4.67.1-pyhd8ed1ab_1.conda
# Extracting zstandard-0.25.0-py312h5253ce2_1.conda
# Extracting conda-package-streaming-0.12.0-pyhd8ed1ab_0.conda
# Extracting urllib3-2.5.0-pyhd8ed1ab_0.conda
# Extracting requests-2.32.5-pyhd8ed1ab_0.conda
# Extracting conda-package-handling-2.4.0-pyh7900ff3_2.conda
# Extracting conda-25.11.0-py312h7900ff3_0.conda
# Extracting conda-libmamba-solver-25.11.0-pyhd8ed1ab_0.conda
#
# Installing base environment...
#
# Transaction
#
#   Prefix: /home/miniforge3
#
#   Updating specs:
#
#    - _libgcc_mutex==0.1=conda_forge
#    - ca-certificates==2025.11.12=hbd8a1cb_0
#    - libgomp==15.2.0=he0feb66_15
#    - nlohmann_json-abi==3.12.0=h0f90c79_1
#    - pybind11-abi==11=hc364b38_1
#    - python_abi==3.12=8_cp312
#    - tzdata==2025b=h78e105d_0
#    - _openmp_mutex==4.5=2_gnu
#    - libgcc==15.2.0=he0feb66_15
#    - bzip2==1.0.8=hda65f42_8
#    - c-ares==1.34.5=hb9d3cd8_0
#    - keyutils==1.6.3=hb9d3cd8_0
#    - libexpat==2.7.3=hecca717_0
#    - libffi==3.5.2=h9ec8514_0
#    - libgcc-ng==15.2.0=h69a702a_15
#    - libiconv==1.18=h3b78370_2
#    - liblzma==5.8.1=hb9d3cd8_2
#    - libnsl==2.0.1=hb9d3cd8_1
#    - libstdcxx==15.2.0=h934c35e_15
#    - libuuid==2.41.2=h5347b49_1
#    - libzlib==1.3.1=hb9d3cd8_2
#    - lzo==2.10=h280c20c_1002
#    - ncurses==6.5=h2d0b736_3
#    - openssl==3.6.0=h26f9b46_0
#    - reproc==14.2.5.post0=hb9d3cd8_0
#    - cpp-expected==1.3.1=h171cf75_0
#    - fmt==12.0.0=h2b0788b_0
#    - libedit==3.1.20250104=pl5321h7949ede_0
#    - libev==4.33=hd590300_2
#    - libsolv==0.7.35=h9463b59_0
#    - libsqlite==3.51.1=h0c1763c_0
#    - libssh2==1.11.1=hcf80075_0
#    - libstdcxx-ng==15.2.0=hdf11a46_15
#    - libxcrypt==4.4.36=hd590300_1
#    - libxml2-16==2.15.1=hf2a90c1_0
#    - lz4-c==1.10.0=h5888daf_1
#    - readline==8.2=h8c095d6_2
#    - reproc-cpp==14.2.5.post0=h5888daf_0
#    - simdjson==4.2.2=hb700be7_0
#    - tk==8.6.13=noxft_ha0e22de_103
#    - yaml-cpp==0.8.0=h3f2d84a_0
#    - zstd==1.5.7=hb78ec9c_6
#    - krb5==1.21.3=h659f571_0
#    - ld_impl_linux-64==2.45=default_hbd61a6d_104
#    - libnghttp2==1.67.0=had1ee68_0
#    - libxml2==2.15.1=h031cc0b_0
#    - libarchive==3.8.2=gpl_h7be2006_100
#    - libcurl==8.17.0=h4e3cde8_0
#    - python==3.12.12=hd63d673_1_cpython
#    - libmamba==2.4.0=hed7d790_1
#    - menuinst==2.4.1=py312h7900ff3_0
#    - archspec==0.2.5=pyhd8ed1ab_0
#    - boltons==25.0.0=pyhd8ed1ab_0
#    - brotli-python==1.2.0=py312hdb49522_1
#    - certifi==2025.11.12=pyhd8ed1ab_0
#    - charset-normalizer==3.4.4=pyhd8ed1ab_0
#    - colorama==0.4.6=pyhd8ed1ab_1
#    - distro==1.9.0=pyhd8ed1ab_1
#    - frozendict==2.4.7=py312h4c3975b_0
#    - hpack==4.1.0=pyhd8ed1ab_0
#    - hyperframe==6.1.0=pyhd8ed1ab_0
#    - idna==3.11=pyhd8ed1ab_0
#    - jsonpointer==3.0.0=py312h7900ff3_2
#    - libmambapy==2.4.0=py312h17091a9_1
#    - mamba==2.4.0=h7ae174a_1
#    - msgpack-python==1.1.2=py312hd9148b4_1
#    - packaging==25.0=pyh29332c3_1
#    - platformdirs==4.5.0=pyhcf101f3_0
#    - pluggy==1.6.0=pyhf9edf01_1
#    - pycosat==0.6.6=py312h4c3975b_3
#    - pycparser==2.22=pyh29332c3_1
#    - pysocks==1.7.1=pyha55dd90_7
#    - ruamel.yaml.clib==0.2.14=py312h4c3975b_0
#    - setuptools==80.9.0=pyhff2d567_0
#    - truststore==0.10.3=pyhe01879c_0
#    - wheel==0.45.1=pyhd8ed1ab_1
#    - cffi==2.0.0=py312h460c074_1
#    - h2==4.3.0=pyhcf101f3_0
#    - jsonpatch==1.33=pyhd8ed1ab_1
#    - pip==25.3=pyh8b19718_0
#    - ruamel.yaml==0.18.16=py312h4c3975b_0
#    - tqdm==4.67.1=pyhd8ed1ab_1
#    - zstandard==0.25.0=py312h5253ce2_1
#    - conda-package-streaming==0.12.0=pyhd8ed1ab_0
#    - urllib3==2.5.0=pyhd8ed1ab_0
#    - requests==2.32.5=pyhd8ed1ab_0
#    - conda-package-handling==2.4.0=pyh7900ff3_2
#    - conda==25.11.0=py312h7900ff3_0
#    - conda-libmamba-solver==25.11.0=pyhd8ed1ab_0
#
#
#   Package                         Version  Build                 Channel         Size
# ───────────────────────────────────────────────────────────────────────────────────────
#   Install:
# ───────────────────────────────────────────────────────────────────────────────────────
#
#   + _libgcc_mutex                     0.1  conda_forge           conda-forge
#   + _openmp_mutex                     4.5  2_gnu                 conda-forge
#   + archspec                        0.2.5  pyhd8ed1ab_0          conda-forge
#   + boltons                        25.0.0  pyhd8ed1ab_0          conda-forge
#   + brotli-python                   1.2.0  py312hdb49522_1       conda-forge
#   + bzip2                           1.0.8  hda65f42_8            conda-forge
#   + c-ares                         1.34.5  hb9d3cd8_0            conda-forge
#   + ca-certificates            2025.11.12  hbd8a1cb_0            conda-forge
#   + certifi                    2025.11.12  pyhd8ed1ab_0          conda-forge
#   + cffi                            2.0.0  py312h460c074_1       conda-forge
#   + charset-normalizer              3.4.4  pyhd8ed1ab_0          conda-forge
#   + colorama                        0.4.6  pyhd8ed1ab_1          conda-forge
#   + conda                         25.11.0  py312h7900ff3_0       conda-forge
#   + conda-libmamba-solver         25.11.0  pyhd8ed1ab_0          conda-forge
#   + conda-package-handling          2.4.0  pyh7900ff3_2          conda-forge
#   + conda-package-streaming        0.12.0  pyhd8ed1ab_0          conda-forge
#   + cpp-expected                    1.3.1  h171cf75_0            conda-forge
#   + distro                          1.9.0  pyhd8ed1ab_1          conda-forge
#   + fmt                            12.0.0  h2b0788b_0            conda-forge
#   + frozendict                      2.4.7  py312h4c3975b_0       conda-forge
#   + h2                              4.3.0  pyhcf101f3_0          conda-forge
#   + hpack                           4.1.0  pyhd8ed1ab_0          conda-forge
#   + hyperframe                      6.1.0  pyhd8ed1ab_0          conda-forge
#   + idna                             3.11  pyhd8ed1ab_0          conda-forge
#   + jsonpatch                        1.33  pyhd8ed1ab_1          conda-forge
#   + jsonpointer                     3.0.0  py312h7900ff3_2       conda-forge
#   + keyutils                        1.6.3  hb9d3cd8_0            conda-forge
#   + krb5                           1.21.3  h659f571_0            conda-forge
#   + ld_impl_linux-64                 2.45  default_hbd61a6d_104  conda-forge
#   + libarchive                      3.8.2  gpl_h7be2006_100      conda-forge
#   + libcurl                        8.17.0  h4e3cde8_0            conda-forge
#   + libedit                  3.1.20250104  pl5321h7949ede_0      conda-forge
#   + libev                            4.33  hd590300_2            conda-forge
#   + libexpat                        2.7.3  hecca717_0            conda-forge
#   + libffi                          3.5.2  h9ec8514_0            conda-forge
#   + libgcc                         15.2.0  he0feb66_15           conda-forge
#   + libgcc-ng                      15.2.0  h69a702a_15           conda-forge
#   + libgomp                        15.2.0  he0feb66_15           conda-forge
#   + libiconv                         1.18  h3b78370_2            conda-forge
#   + liblzma                         5.8.1  hb9d3cd8_2            conda-forge
#   + libmamba                        2.4.0  hed7d790_1            conda-forge
#   + libmambapy                      2.4.0  py312h17091a9_1       conda-forge
#   + libnghttp2                     1.67.0  had1ee68_0            conda-forge
#   + libnsl                          2.0.1  hb9d3cd8_1            conda-forge
#   + libsolv                        0.7.35  h9463b59_0            conda-forge
#   + libsqlite                      3.51.1  h0c1763c_0            conda-forge
#   + libssh2                        1.11.1  hcf80075_0            conda-forge
#   + libstdcxx                      15.2.0  h934c35e_15           conda-forge
#   + libstdcxx-ng                   15.2.0  hdf11a46_15           conda-forge
#   + libuuid                        2.41.2  h5347b49_1            conda-forge
#   + libxcrypt                      4.4.36  hd590300_1            conda-forge
#   + libxml2                        2.15.1  h031cc0b_0            conda-forge
#   + libxml2-16                     2.15.1  hf2a90c1_0            conda-forge
#   + libzlib                         1.3.1  hb9d3cd8_2            conda-forge
#   + lz4-c                          1.10.0  h5888daf_1            conda-forge
#   + lzo                              2.10  h280c20c_1002         conda-forge
#   + mamba                           2.4.0  h7ae174a_1            conda-forge
#   + menuinst                        2.4.1  py312h7900ff3_0       conda-forge
#   + msgpack-python                  1.1.2  py312hd9148b4_1       conda-forge
#   + ncurses                           6.5  h2d0b736_3            conda-forge
#   + nlohmann_json-abi              3.12.0  h0f90c79_1            conda-forge
#   + openssl                         3.6.0  h26f9b46_0            conda-forge
#   + packaging                        25.0  pyh29332c3_1          conda-forge
#   + pip                              25.3  pyh8b19718_0          conda-forge
#   + platformdirs                    4.5.0  pyhcf101f3_0          conda-forge
#   + pluggy                          1.6.0  pyhf9edf01_1          conda-forge
#   + pybind11-abi                       11  hc364b38_1            conda-forge
#   + pycosat                         0.6.6  py312h4c3975b_3       conda-forge
#   + pycparser                        2.22  pyh29332c3_1          conda-forge
#   + pysocks                         1.7.1  pyha55dd90_7          conda-forge
#   + python                        3.12.12  hd63d673_1_cpython    conda-forge
#   + python_abi                       3.12  8_cp312               conda-forge
#   + readline                          8.2  h8c095d6_2            conda-forge
#   + reproc                   14.2.5.post0  hb9d3cd8_0            conda-forge
#   + reproc-cpp               14.2.5.post0  h5888daf_0            conda-forge
#   + requests                       2.32.5  pyhd8ed1ab_0          conda-forge
#   + ruamel.yaml                   0.18.16  py312h4c3975b_0       conda-forge
#   + ruamel.yaml.clib               0.2.14  py312h4c3975b_0       conda-forge
#   + setuptools                     80.9.0  pyhff2d567_0          conda-forge
#   + simdjson                        4.2.2  hb700be7_0            conda-forge
#   + tk                             8.6.13  noxft_ha0e22de_103    conda-forge
#   + tqdm                           4.67.1  pyhd8ed1ab_1          conda-forge
#   + truststore                     0.10.3  pyhe01879c_0          conda-forge
#   + tzdata                          2025b  h78e105d_0            conda-forge
#   + urllib3                         2.5.0  pyhd8ed1ab_0          conda-forge
#   + wheel                          0.45.1  pyhd8ed1ab_1          conda-forge
#   + yaml-cpp                        0.8.0  h3f2d84a_0            conda-forge
#   + zstandard                      0.25.0  py312h5253ce2_1       conda-forge
#   + zstd                            1.5.7  hb78ec9c_6            conda-forge
#
#   Summary:
#
#   Install: 89 packages
#
#   Total download: 0 B
#
# ───────────────────────────────────────────────────────────────────────────────────────
#
#
#
# Transaction starting
# Linking _libgcc_mutex-0.1-conda_forge
# Linking ca-certificates-2025.11.12-hbd8a1cb_0
# Linking libgomp-15.2.0-he0feb66_15
# Linking nlohmann_json-abi-3.12.0-h0f90c79_1
# Linking pybind11-abi-11-hc364b38_1
# Linking python_abi-3.12-8_cp312
# Linking tzdata-2025b-h78e105d_0
# Linking _openmp_mutex-4.5-2_gnu
# Linking libgcc-15.2.0-he0feb66_15
# Linking bzip2-1.0.8-hda65f42_8
# Linking c-ares-1.34.5-hb9d3cd8_0
# Linking keyutils-1.6.3-hb9d3cd8_0
# Linking libexpat-2.7.3-hecca717_0
# Linking libffi-3.5.2-h9ec8514_0
# Linking libgcc-ng-15.2.0-h69a702a_15
# Linking libiconv-1.18-h3b78370_2
# Linking liblzma-5.8.1-hb9d3cd8_2
# Linking libnsl-2.0.1-hb9d3cd8_1
# Linking libstdcxx-15.2.0-h934c35e_15
# Linking libuuid-2.41.2-h5347b49_1
# Linking libzlib-1.3.1-hb9d3cd8_2
# Linking lzo-2.10-h280c20c_1002
# Linking ncurses-6.5-h2d0b736_3
# Linking openssl-3.6.0-h26f9b46_0
# Linking reproc-14.2.5.post0-hb9d3cd8_0
# Linking cpp-expected-1.3.1-h171cf75_0
# Linking fmt-12.0.0-h2b0788b_0
# Linking libedit-3.1.20250104-pl5321h7949ede_0
# Linking libev-4.33-hd590300_2
# Linking libsolv-0.7.35-h9463b59_0
# Linking libsqlite-3.51.1-h0c1763c_0
# Linking libssh2-1.11.1-hcf80075_0
# Linking libstdcxx-ng-15.2.0-hdf11a46_15
# Linking libxcrypt-4.4.36-hd590300_1
# Linking libxml2-16-2.15.1-hf2a90c1_0
# Linking lz4-c-1.10.0-h5888daf_1
# Linking readline-8.2-h8c095d6_2
# Linking reproc-cpp-14.2.5.post0-h5888daf_0
# Linking simdjson-4.2.2-hb700be7_0
# Linking tk-8.6.13-noxft_ha0e22de_103
# Linking yaml-cpp-0.8.0-h3f2d84a_0
# Linking zstd-1.5.7-hb78ec9c_6
# Linking krb5-1.21.3-h659f571_0
# Linking ld_impl_linux-64-2.45-default_hbd61a6d_104
# Linking libnghttp2-1.67.0-had1ee68_0
# Linking libxml2-2.15.1-h031cc0b_0
# Linking libarchive-3.8.2-gpl_h7be2006_100
# Linking libcurl-8.17.0-h4e3cde8_0
# Linking python-3.12.12-hd63d673_1_cpython
# Linking libmamba-2.4.0-hed7d790_1
# Linking menuinst-2.4.1-py312h7900ff3_0
# Linking archspec-0.2.5-pyhd8ed1ab_0
# Linking boltons-25.0.0-pyhd8ed1ab_0
# Linking brotli-python-1.2.0-py312hdb49522_1
# Linking certifi-2025.11.12-pyhd8ed1ab_0
# Linking charset-normalizer-3.4.4-pyhd8ed1ab_0
# Linking colorama-0.4.6-pyhd8ed1ab_1
# Linking distro-1.9.0-pyhd8ed1ab_1
# Linking frozendict-2.4.7-py312h4c3975b_0
# Linking hpack-4.1.0-pyhd8ed1ab_0
# Linking hyperframe-6.1.0-pyhd8ed1ab_0
# Linking idna-3.11-pyhd8ed1ab_0
# Linking jsonpointer-3.0.0-py312h7900ff3_2
# Linking libmambapy-2.4.0-py312h17091a9_1
# Linking mamba-2.4.0-h7ae174a_1
# Linking msgpack-python-1.1.2-py312hd9148b4_1
# Linking packaging-25.0-pyh29332c3_1
# Linking platformdirs-4.5.0-pyhcf101f3_0
# Linking pluggy-1.6.0-pyhf9edf01_1
# Linking pycosat-0.6.6-py312h4c3975b_3
# Linking pycparser-2.22-pyh29332c3_1
# Linking pysocks-1.7.1-pyha55dd90_7
# Linking ruamel.yaml.clib-0.2.14-py312h4c3975b_0
# Linking setuptools-80.9.0-pyhff2d567_0
# Linking truststore-0.10.3-pyhe01879c_0
# Linking wheel-0.45.1-pyhd8ed1ab_1
# Linking cffi-2.0.0-py312h460c074_1
# Linking h2-4.3.0-pyhcf101f3_0
# Linking jsonpatch-1.33-pyhd8ed1ab_1
# Linking pip-25.3-pyh8b19718_0
# Linking ruamel.yaml-0.18.16-py312h4c3975b_0
# Linking tqdm-4.67.1-pyhd8ed1ab_1
# Linking zstandard-0.25.0-py312h5253ce2_1
# Linking conda-package-streaming-0.12.0-pyhd8ed1ab_0
# Linking urllib3-2.5.0-pyhd8ed1ab_0
# Linking requests-2.32.5-pyhd8ed1ab_0
# Linking conda-package-handling-2.4.0-pyh7900ff3_2
# Linking conda-25.11.0-py312h7900ff3_0
# Linking conda-libmamba-solver-25.11.0-pyhd8ed1ab_0
#
# Transaction finished
#
# installation finished.
# WARNING:
#     You currently have a PYTHONPATH environment variable set. This may cause
#     unexpected behavior when running the Python interpreter in Miniforge3.
#     For best results, please verify that your PYTHONPATH only points to
#     directories of packages that are compatible with the Python interpreter
#     in Miniforge3: /home/miniforge3
# env: PATH=/home/miniforge3/bin:/usr/local/nvidia/bin:/usr/local/cuda/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/tools/node/bin:/tools/google-cloud-sdk/bin
# Miniforge installation complete and PATH updated.

# %%
import os
import sys

# Add conda python to PATH
conda_path = '/home/miniforge3/bin'
new_path = f"{conda_path}:{os.environ['PATH']}"
os.environ['PATH'] = new_path
# %env PATH=$new_path

# # Use conda python for subprocess calls
conda_site_packages = '/home/miniforge3/lib/python3.12/site-packages'
sys.path.insert(0, conda_site_packages)
os.environ['PYTHONPATH'] = f"{conda_site_packages}:{os.environ['PYTHONPATH']}"
pythonpath = os.environ['PYTHONPATH']
# %env PYTHONPATH=$pythonpath

# # Verify which python is being used
# !which python
# !/home/miniforge3/bin/python --version
# Out:
# /home/miniforge3/bin/python
# Python 3.12.12

# %%
! pip install openmim
! pip install --upgrade setuptools pip
! mim install mmcv==2.1.0
! mim install --upgrade mmsegmentation
# Out:
# ERROR: Ignored the following yanked versions: 0.5.2
# ERROR: Could not find a version that satisfies the requirement mmcv==2.0.0rc5 (from versions: 0.2.0, 0.2.1, 0.2.2, 0.2.3, 0.2.4, 0.2.5, 0.2.6, 0.2.7, 0.2.8, 0.2.9, 0.2.10, 0.2.11, 0.2.12, 0.2.13, 0.2.14, 0.2.15, 0.2.16, 0.3.0, 0.3.1, 0.3.2, 0.4.0, 0.4.2, 0.4.3, 0.4.4, 0.5.0, 0.5.1, 0.5.3, 0.5.4, 0.5.5, 0.5.6, 0.5.7, 0.5.8, 0.5.9, 0.6.0, 0.6.1, 0.6.2, 1.0rc0, 1.0rc2, 1.0.0, 1.0.1, 1.0.2, 1.0.3, 1.0.4, 1.0.5, 1.1.0, 1.1.1, 1.1.2, 1.1.3, 1.1.4, 1.1.5, 1.1.6, 1.2.0, 1.2.1, 1.2.2, 1.2.3, 1.2.4, 1.2.5, 1.2.6, 1.2.7, 1.3.0, 1.3.1, 1.3.3, 1.3.4, 1.3.5, 1.3.6, 1.3.7, 1.3.8, 1.3.9, 1.3.10, 1.3.11, 1.3.12, 1.3.13, 1.3.14, 1.3.15, 1.3.16, 1.3.17, 1.3.18, 1.4.0, 1.4.1, 1.4.2, 1.4.3, 1.4.4, 1.4.5, 1.4.6, 1.4.7, 1.4.8, 1.5.0, 1.5.1, 1.5.2, 1.5.3, 1.6.0, 1.6.1, 1.6.2, 1.7.0, 1.7.1, 1.7.2, 2.0.0rc1, 2.0.0rc2, 2.0.0rc3, 2.0.0rc4, 2.0.0, 2.0.1, 2.1.0, 2.2.0)
# ERROR: No matching distribution found for mmcv==2.0.0rc5
# Requirement already satisfied: openmim in ./miniforge3/lib/python3.12/site-packages (0.3.9)
# Requirement already satisfied: Click in ./miniforge3/lib/python3.12/site-packages (from openmim) (8.3.1)
# Requirement already satisfied: colorama in ./miniforge3/lib/python3.12/site-packages (from openmim) (0.4.6)
# Requirement already satisfied: model-index in ./miniforge3/lib/python3.12/site-packages (from openmim) (0.1.11)
# Requirement already satisfied: opendatalab in ./miniforge3/lib/python3.12/site-packages (from openmim) (0.0.10)
# Requirement already satisfied: pandas in ./miniforge3/lib/python3.12/site-packages (from openmim) (2.3.3)
# Requirement already satisfied: pip>=19.3 in ./miniforge3/lib/python3.12/site-packages (from openmim) (25.3)
# Requirement already satisfied: requests in ./miniforge3/lib/python3.12/site-packages (from openmim) (2.28.2)
# Requirement already satisfied: rich in ./miniforge3/lib/python3.12/site-packages (from openmim) (14.2.0)
# Requirement already satisfied: tabulate in ./miniforge3/lib/python3.12/site-packages (from openmim) (0.9.0)
# Requirement already satisfied: pyyaml in ./miniforge3/lib/python3.12/site-packages (from model-index->openmim) (6.0.3)
# Requirement already satisfied: markdown in ./miniforge3/lib/python3.12/site-packages (from model-index->openmim) (3.10)
# Requirement already satisfied: ordered-set in ./miniforge3/lib/python3.12/site-packages (from model-index->openmim) (4.1.0)
# Requirement already satisfied: pycryptodome in ./miniforge3/lib/python3.12/site-packages (from opendatalab->openmim) (3.23.0)
# Requirement already satisfied: tqdm in ./miniforge3/lib/python3.12/site-packages (from opendatalab->openmim) (4.65.2)
# Requirement already satisfied: openxlab in ./miniforge3/lib/python3.12/site-packages (from opendatalab->openmim) (0.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./miniforge3/lib/python3.12/site-packages (from requests->openmim) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in ./miniforge3/lib/python3.12/site-packages (from requests->openmim) (3.11)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in ./miniforge3/lib/python3.12/site-packages (from requests->openmim) (1.26.20)
# Requirement already satisfied: certifi>=2017.4.17 in ./miniforge3/lib/python3.12/site-packages (from requests->openmim) (2025.11.12)
# Requirement already satisfied: filelock~=3.14.0 in ./miniforge3/lib/python3.12/site-packages (from openxlab->opendatalab->openmim) (3.14.0)
# Requirement already satisfied: oss2~=2.17.0 in ./miniforge3/lib/python3.12/site-packages (from openxlab->opendatalab->openmim) (2.17.0)
# Collecting packaging~=24.0 (from openxlab->opendatalab->openmim)
#   Downloading packaging-24.2-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: pytz~=2023.3 in ./miniforge3/lib/python3.12/site-packages (from openxlab->opendatalab->openmim) (2023.4)
# Collecting rich (from openmim)
#   Downloading rich-13.4.2-py3-none-any.whl.metadata (18 kB)
# Collecting setuptools~=60.2.0 (from openxlab->opendatalab->openmim)
#   Downloading setuptools-60.2.0-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: crcmod>=1.7 in ./miniforge3/lib/python3.12/site-packages (from oss2~=2.17.0->openxlab->opendatalab->openmim) (1.7)
# Requirement already satisfied: aliyun-python-sdk-kms>=2.4.1 in ./miniforge3/lib/python3.12/site-packages (from oss2~=2.17.0->openxlab->opendatalab->openmim) (2.16.5)
# Requirement already satisfied: aliyun-python-sdk-core>=2.13.12 in ./miniforge3/lib/python3.12/site-packages (from oss2~=2.17.0->openxlab->opendatalab->openmim) (2.16.0)
# Requirement already satisfied: six in ./miniforge3/lib/python3.12/site-packages (from oss2~=2.17.0->openxlab->opendatalab->openmim) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in ./miniforge3/lib/python3.12/site-packages (from rich->openmim) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in ./miniforge3/lib/python3.12/site-packages (from rich->openmim) (2.19.2)
# Requirement already satisfied: jmespath<1.0.0,>=0.9.3 in ./miniforge3/lib/python3.12/site-packages (from aliyun-python-sdk-core>=2.13.12->oss2~=2.17.0->openxlab->opendatalab->openmim) (0.10.0)
# Requirement already satisfied: cryptography>=3.0.0 in ./miniforge3/lib/python3.12/site-packages (from aliyun-python-sdk-core>=2.13.12->oss2~=2.17.0->openxlab->opendatalab->openmim) (46.0.3)
# Requirement already satisfied: cffi>=2.0.0 in ./miniforge3/lib/python3.12/site-packages (from cryptography>=3.0.0->aliyun-python-sdk-core>=2.13.12->oss2~=2.17.0->openxlab->opendatalab->openmim) (2.0.0)
# Requirement already satisfied: pycparser in ./miniforge3/lib/python3.12/site-packages (from cffi>=2.0.0->cryptography>=3.0.0->aliyun-python-sdk-core>=2.13.12->oss2~=2.17.0->openxlab->opendatalab->openmim) (2.22)
# Requirement already satisfied: mdurl~=0.1 in ./miniforge3/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich->openmim) (0.1.2)
# Requirement already satisfied: numpy>=1.26.0 in ./miniforge3/lib/python3.12/site-packages (from pandas->openmim) (2.2.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./miniforge3/lib/python3.12/site-packages (from pandas->openmim) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in ./miniforge3/lib/python3.12/site-packages (from pandas->openmim) (2025.3)
# Downloading packaging-24.2-py3-none-any.whl (65 kB)
# Downloading rich-13.4.2-py3-none-any.whl (239 kB)
# Downloading setuptools-60.2.0-py3-none-any.whl (953 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 953.1/953.1 kB 41.6 MB/s  0:00:00
# Installing collected packages: setuptools, packaging, rich
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 80.9.0
#     Uninstalling setuptools-80.9.0:
#       Successfully uninstalled setuptools-80.9.0 0/3 [setuptools]
#   Attempting uninstall: packaging━━━━━━━━━━━━━━━ 0/3 [setuptools]
#     Found existing installation: packaging 25.0m 0/3 [setuptools]
#     Uninstalling packaging-25.0:━━━━━━━━━━━━ 0/3 [setuptools]
#       Successfully uninstalled packaging-25.0 0/3 [setuptools]
#   Attempting uninstall: rich━━━━━━━━━━━━━━━━ 0/3 [setuptools]
#     Found existing installation: rich 14.2.0 0/3 [setuptools]
#     Uninstalling rich-14.2.0:━━━━━━━━━━━━━━━ 0/3 [setuptools]
#       Successfully uninstalled rich-14.2.0━━ 0/3 [setuptools]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3/3 [rich]2/3 [rich]
# Successfully installed packaging-24.2 rich-13.4.2 setuptools-60.2.0
# Requirement already satisfied: setuptools in ./miniforge3/lib/python3.12/site-packages (60.2.0)
# Collecting setuptools
#   Using cached setuptools-80.9.0-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: pip in ./miniforge3/lib/python3.12/site-packages (25.3)
# Using cached setuptools-80.9.0-py3-none-any.whl (1.2 MB)
# Installing collected packages: setuptools
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 60.2.0
#     Uninstalling setuptools-60.2.0:
#       Successfully uninstalled setuptools-60.2.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# openxlab 0.1.3 requires setuptools~=60.2.0, but you have setuptools 80.9.0 which is incompatible.
# Successfully installed setuptools-80.9.0
# /home/miniforge3/lib/python3.12/site-packages/mim/commands/list.py:4: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# Looking in links: https://download.openmmlab.com/mmcv/dist/cu126/torch2.9.0/index.html
# Requirement already satisfied: mmsegmentation in ./miniforge3/lib/python3.12/site-packages (1.2.2)
# Requirement already satisfied: matplotlib in ./miniforge3/lib/python3.12/site-packages (from mmsegmentation) (3.10.8)
# Requirement already satisfied: numpy in ./miniforge3/lib/python3.12/site-packages (from mmsegmentation) (2.2.6)
# Requirement already satisfied: packaging in ./miniforge3/lib/python3.12/site-packages (from mmsegmentation) (24.2)
# Requirement already satisfied: prettytable in ./miniforge3/lib/python3.12/site-packages (from mmsegmentation) (3.17.0)
# Requirement already satisfied: scipy in ./miniforge3/lib/python3.12/site-packages (from mmsegmentation) (1.16.3)
# Ignoring mmcv: markers 'extra == "mim"' don't match your environment
# Ignoring mmengine: markers 'extra == "mim"' don't match your environment
# Requirement already satisfied: contourpy>=1.0.1 in ./miniforge3/lib/python3.12/site-packages (from matplotlib->mmsegmentation) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in ./miniforge3/lib/python3.12/site-packages (from matplotlib->mmsegmentation) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in ./miniforge3/lib/python3.12/site-packages (from matplotlib->mmsegmentation) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./miniforge3/lib/python3.12/site-packages (from matplotlib->mmsegmentation) (1.4.9)
# Requirement already satisfied: pillow>=8 in ./miniforge3/lib/python3.12/site-packages (from matplotlib->mmsegmentation) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in ./miniforge3/lib/python3.12/site-packages (from matplotlib->mmsegmentation) (3.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in ./miniforge3/lib/python3.12/site-packages (from matplotlib->mmsegmentation) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in ./miniforge3/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib->mmsegmentation) (1.17.0)
# Requirement already satisfied: wcwidth in ./miniforge3/lib/python3.12/site-packages (from prettytable->mmsegmentation) (0.2.14)

# %%
! pip install mmcv==2.1.0
# Out:
# Collecting mmcv==2.1.0
#   Using cached mmcv-2.1.0-py2.py3-none-any.whl
# Requirement already satisfied: addict in ./miniforge3/lib/python3.12/site-packages (from mmcv==2.1.0) (2.4.0)
# Requirement already satisfied: mmengine>=0.3.0 in ./miniforge3/lib/python3.12/site-packages (from mmcv==2.1.0) (0.10.7)
# Requirement already satisfied: numpy in ./miniforge3/lib/python3.12/site-packages (from mmcv==2.1.0) (2.2.6)
# Requirement already satisfied: packaging in ./miniforge3/lib/python3.12/site-packages (from mmcv==2.1.0) (24.2)
# Requirement already satisfied: Pillow in ./miniforge3/lib/python3.12/site-packages (from mmcv==2.1.0) (12.0.0)
# Requirement already satisfied: pyyaml in ./miniforge3/lib/python3.12/site-packages (from mmcv==2.1.0) (6.0.3)
# Requirement already satisfied: yapf in ./miniforge3/lib/python3.12/site-packages (from mmcv==2.1.0) (0.43.0)
# Requirement already satisfied: opencv-python>=3 in ./miniforge3/lib/python3.12/site-packages (from mmcv==2.1.0) (4.12.0.88)
# Requirement already satisfied: matplotlib in ./miniforge3/lib/python3.12/site-packages (from mmengine>=0.3.0->mmcv==2.1.0) (3.10.8)
# Requirement already satisfied: rich in ./miniforge3/lib/python3.12/site-packages (from mmengine>=0.3.0->mmcv==2.1.0) (13.4.2)
# Requirement already satisfied: termcolor in ./miniforge3/lib/python3.12/site-packages (from mmengine>=0.3.0->mmcv==2.1.0) (3.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in ./miniforge3/lib/python3.12/site-packages (from matplotlib->mmengine>=0.3.0->mmcv==2.1.0) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in ./miniforge3/lib/python3.12/site-packages (from matplotlib->mmengine>=0.3.0->mmcv==2.1.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in ./miniforge3/lib/python3.12/site-packages (from matplotlib->mmengine>=0.3.0->mmcv==2.1.0) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./miniforge3/lib/python3.12/site-packages (from matplotlib->mmengine>=0.3.0->mmcv==2.1.0) (1.4.9)
# Requirement already satisfied: pyparsing>=3 in ./miniforge3/lib/python3.12/site-packages (from matplotlib->mmengine>=0.3.0->mmcv==2.1.0) (3.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in ./miniforge3/lib/python3.12/site-packages (from matplotlib->mmengine>=0.3.0->mmcv==2.1.0) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in ./miniforge3/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib->mmengine>=0.3.0->mmcv==2.1.0) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in ./miniforge3/lib/python3.12/site-packages (from rich->mmengine>=0.3.0->mmcv==2.1.0) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in ./miniforge3/lib/python3.12/site-packages (from rich->mmengine>=0.3.0->mmcv==2.1.0) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in ./miniforge3/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich->mmengine>=0.3.0->mmcv==2.1.0) (0.1.2)
# Requirement already satisfied: platformdirs>=3.5.1 in ./miniforge3/lib/python3.12/site-packages (from yapf->mmcv==2.1.0) (4.5.0)
# Installing collected packages: mmcv
#   Attempting uninstall: mmcv
#     Found existing installation: mmcv 2.0.0rc4
#     Uninstalling mmcv-2.0.0rc4:
#       Successfully uninstalled mmcv-2.0.0rc4
# Successfully installed mmcv-2.1.0

# %%
! pip install mmcv==2.1.0
# Out:
# Collecting mmcv==2.1.0
#   Using cached mmcv-2.1.0-py2.py3-none-any.whl
# Requirement already satisfied: addict in ./miniforge3/lib/python3.12/site-packages (from mmcv==2.1.0) (2.4.0)
# Requirement already satisfied: mmengine>=0.3.0 in ./miniforge3/lib/python3.12/site-packages (from mmcv==2.1.0) (0.10.7)
# Requirement already satisfied: numpy in ./miniforge3/lib/python3.12/site-packages (from mmcv==2.1.0) (2.2.6)
# Requirement already satisfied: packaging in ./miniforge3/lib/python3.12/site-packages (from mmcv==2.1.0) (24.2)
# Requirement already satisfied: Pillow in ./miniforge3/lib/python3.12/site-packages (from mmcv==2.1.0) (12.0.0)
# Requirement already satisfied: pyyaml in ./miniforge3/lib/python3.12/site-packages (from mmcv==2.1.0) (6.0.3)
# Requirement already satisfied: yapf in ./miniforge3/lib/python3.12/site-packages (from mmcv==2.1.0) (0.43.0)
# Requirement already satisfied: opencv-python>=3 in ./miniforge3/lib/python3.12/site-packages (from mmcv==2.1.0) (4.12.0.88)
# Requirement already satisfied: matplotlib in ./miniforge3/lib/python3.12/site-packages (from mmengine>=0.3.0->mmcv==2.1.0) (3.10.8)
# Requirement already satisfied: rich in ./miniforge3/lib/python3.12/site-packages (from mmengine>=0.3.0->mmcv==2.1.0) (13.4.2)
# Requirement already satisfied: termcolor in ./miniforge3/lib/python3.12/site-packages (from mmengine>=0.3.0->mmcv==2.1.0) (3.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in ./miniforge3/lib/python3.12/site-packages (from matplotlib->mmengine>=0.3.0->mmcv==2.1.0) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in ./miniforge3/lib/python3.12/site-packages (from matplotlib->mmengine>=0.3.0->mmcv==2.1.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in ./miniforge3/lib/python3.12/site-packages (from matplotlib->mmengine>=0.3.0->mmcv==2.1.0) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./miniforge3/lib/python3.12/site-packages (from matplotlib->mmengine>=0.3.0->mmcv==2.1.0) (1.4.9)
# Requirement already satisfied: pyparsing>=3 in ./miniforge3/lib/python3.12/site-packages (from matplotlib->mmengine>=0.3.0->mmcv==2.1.0) (3.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in ./miniforge3/lib/python3.12/site-packages (from matplotlib->mmengine>=0.3.0->mmcv==2.1.0) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in ./miniforge3/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib->mmengine>=0.3.0->mmcv==2.1.0) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in ./miniforge3/lib/python3.12/site-packages (from rich->mmengine>=0.3.0->mmcv==2.1.0) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in ./miniforge3/lib/python3.12/site-packages (from rich->mmengine>=0.3.0->mmcv==2.1.0) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in ./miniforge3/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich->mmengine>=0.3.0->mmcv==2.1.0) (0.1.2)
# Requirement already satisfied: platformdirs>=3.5.1 in ./miniforge3/lib/python3.12/site-packages (from yapf->mmcv==2.1.0) (4.5.0)
# Installing collected packages: mmcv
# Successfully installed mmcv-2.1.0

# %%
# !pip uninstall mmcv -y
# !pip cache purge
# !pip install mmcv==2.1.0 --force-reinstall --no-cache-dir
# Out:
# Found existing installation: mmcv 2.1.0
# Uninstalling mmcv-2.1.0:
#   Successfully uninstalled mmcv-2.1.0
# Files removed: 400 (1219.6 MB)
# Collecting mmcv==2.1.0
#   Downloading mmcv-2.1.0.tar.gz (471 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting addict (from mmcv==2.1.0)
#   Downloading addict-2.4.0-py3-none-any.whl.metadata (1.0 kB)
# Collecting mmengine>=0.3.0 (from mmcv==2.1.0)
#   Downloading mmengine-0.10.7-py3-none-any.whl.metadata (20 kB)
# Collecting numpy (from mmcv==2.1.0)
#   Downloading numpy-2.4.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (6.6 kB)
# Collecting packaging (from mmcv==2.1.0)
#   Downloading packaging-25.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting Pillow (from mmcv==2.1.0)
#   Downloading pillow-12.0.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (8.8 kB)
# Collecting pyyaml (from mmcv==2.1.0)
#   Downloading pyyaml-6.0.3-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (2.4 kB)
# Collecting yapf (from mmcv==2.1.0)
#   Downloading yapf-0.43.0-py3-none-any.whl.metadata (46 kB)
# Collecting opencv-python>=3 (from mmcv==2.1.0)
#   Downloading opencv_python-4.12.0.88-cp37-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (19 kB)
# Collecting matplotlib (from mmengine>=0.3.0->mmcv==2.1.0)
#   Downloading matplotlib-3.10.8-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (52 kB)
# Collecting rich (from mmengine>=0.3.0->mmcv==2.1.0)
#   Downloading rich-14.2.0-py3-none-any.whl.metadata (18 kB)
# Collecting termcolor (from mmengine>=0.3.0->mmcv==2.1.0)
#   Downloading termcolor-3.2.0-py3-none-any.whl.metadata (6.4 kB)
# Collecting numpy (from mmcv==2.1.0)
#   Downloading numpy-2.2.6-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (62 kB)
# Collecting contourpy>=1.0.1 (from matplotlib->mmengine>=0.3.0->mmcv==2.1.0)
#   Downloading contourpy-1.3.3-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib->mmengine>=0.3.0->mmcv==2.1.0)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib->mmengine>=0.3.0->mmcv==2.1.0)
#   Downloading fonttools-4.61.1-cp312-cp312-manylinux1_x86_64.manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_5_x86_64.whl.metadata (114 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib->mmengine>=0.3.0->mmcv==2.1.0)
#   Downloading kiwisolver-1.4.9-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (6.3 kB)
# Collecting pyparsing>=3 (from matplotlib->mmengine>=0.3.0->mmcv==2.1.0)
#   Downloading pyparsing-3.3.1-py3-none-any.whl.metadata (5.6 kB)
# Collecting python-dateutil>=2.7 (from matplotlib->mmengine>=0.3.0->mmcv==2.1.0)
#   Downloading python_dateutil-2.9.0.post0-py2.py3-none-any.whl.metadata (8.4 kB)
# Collecting six>=1.5 (from python-dateutil>=2.7->matplotlib->mmengine>=0.3.0->mmcv==2.1.0)
#   Downloading six-1.17.0-py2.py3-none-any.whl.metadata (1.7 kB)
# Collecting markdown-it-py>=2.2.0 (from rich->mmengine>=0.3.0->mmcv==2.1.0)
#   Downloading markdown_it_py-4.0.0-py3-none-any.whl.metadata (7.3 kB)
# Collecting pygments<3.0.0,>=2.13.0 (from rich->mmengine>=0.3.0->mmcv==2.1.0)
#   Downloading pygments-2.19.2-py3-none-any.whl.metadata (2.5 kB)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich->mmengine>=0.3.0->mmcv==2.1.0)
#   Downloading mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Collecting platformdirs>=3.5.1 (from yapf->mmcv==2.1.0)
#   Downloading platformdirs-4.5.1-py3-none-any.whl.metadata (12 kB)
# Downloading mmengine-0.10.7-py3-none-any.whl (452 kB)
# Downloading opencv_python-4.12.0.88-cp37-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (67.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.0/67.0 MB 152.7 MB/s  0:00:00 eta 0:00:01
# Downloading numpy-2.2.6-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.5/16.5 MB 262.7 MB/s  0:00:00
# Downloading addict-2.4.0-py3-none-any.whl (3.8 kB)
# Downloading matplotlib-3.10.8-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (8.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 185.2 MB/s  0:00:00
# Downloading contourpy-1.3.3-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (362 kB)
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.61.1-cp312-cp312-manylinux1_x86_64.manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_5_x86_64.whl (5.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 203.7 MB/s  0:00:00
# Downloading kiwisolver-1.4.9-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 172.6 MB/s  0:00:00
# Downloading packaging-25.0-py3-none-any.whl (66 kB)
# Downloading pillow-12.0.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (7.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 416.9 MB/s  0:00:00
# Downloading pyparsing-3.3.1-py3-none-any.whl (121 kB)
# Downloading python_dateutil-2.9.0.post0-py2.py3-none-any.whl (229 kB)
# Downloading six-1.17.0-py2.py3-none-any.whl (11 kB)
# Downloading pyyaml-6.0.3-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (807 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 807.9/807.9 kB 563.1 MB/s  0:00:00
# Downloading rich-14.2.0-py3-none-any.whl (243 kB)
# Downloading pygments-2.19.2-py3-none-any.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 295.5 MB/s  0:00:00
# Downloading markdown_it_py-4.0.0-py3-none-any.whl (87 kB)
# Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Downloading termcolor-3.2.0-py3-none-any.whl (7.7 kB)
# Downloading yapf-0.43.0-py3-none-any.whl (256 kB)
# Downloading platformdirs-4.5.1-py3-none-any.whl (18 kB)
# Building wheels for collected packages: mmcv
#   Building wheel for mmcv (pyproject.toml) ... done
#   Created wheel for mmcv: filename=mmcv-2.1.0-py2.py3-none-any.whl size=719809 sha256=d3aa2978cf711db42193565f3c3c5977399545d1a859bc361263675b9b7d6628
#   Stored in directory: /tmp/pip-ephem-wheel-cache-fki66i4h/wheels/e9/ed/f4/c494e3ff8fc7f14a8052d170fb3071cd96b7f825274b27df86
# Successfully built mmcv
# Installing collected packages: addict, termcolor, six, pyyaml, pyparsing, pygments, platformdirs, Pillow, packaging, numpy, mdurl, kiwisolver, fonttools, cycler, yapf, python-dateutil, opencv-python, markdown-it-py, contourpy, rich, matplotlib, mmengine, mmcv
#   Attempting uninstall: addict
#     Found existing installation: addict 2.4.0
#     Uninstalling addict-2.4.0:
#       Successfully uninstalled addict-2.4.0
#   Attempting uninstall: termcolor
#     Found existing installation: termcolor 3.2.0
#     Uninstalling termcolor-3.2.0:
#       Successfully uninstalled termcolor-3.2.0
#   Attempting uninstall: six
#     Found existing installation: six 1.17.0
#     Uninstalling six-1.17.0:
#       Successfully uninstalled six-1.17.0━━━━━━━━━━━━━━━━━━━━━━━━━  2/23 [six]
#   Attempting uninstall: pyyaml━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  2/23 [six]
#     Found existing installation: PyYAML 6.0.3━━━━━━━━━━━━━━━━━  2/23 [six]
#     Uninstalling PyYAML-6.0.3:━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  2/23 [six]
#       Successfully uninstalled PyYAML-6.0.3━━━━━━━━━━━━━━━━━━━  2/23 [six]
#   Attempting uninstall: pyparsing━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  3/23 [pyyaml]
#     Found existing installation: pyparsing 3.3.1━━━━━━━━━━━━━━  3/23 [pyyaml]
#     Uninstalling pyparsing-3.3.1:━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  3/23 [pyyaml]
#       Successfully uninstalled pyparsing-3.3.1━━━━━━━━━━━━━━━━  3/23 [pyyaml]
#   Attempting uninstall: pygments━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  3/23 [pyyaml]
#     Found existing installation: Pygments 2.19.2━━━━━━━━━━━━━━  3/23 [pyyaml]
#     Uninstalling Pygments-2.19.2:0m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  5/23 [pygments]
#       Successfully uninstalled Pygments-2.19.2━━━━━━━━━━━━━━━━  5/23 [pygments]
#   Attempting uninstall: platformdirs━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  5/23 [pygments]
#     Found existing installation: platformdirs 4.5.0━━━━━━━━━━━  5/23 [pygments]
#     Uninstalling platformdirs-4.5.0:━━━━━━━━━━━━━━━━━━━━━━━━━━  5/23 [pygments]
#       Successfully uninstalled platformdirs-4.5.0━━━━━━━━━━━━━  5/23 [pygments]
#   Attempting uninstall: Pillowm━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  5/23 [pygments]
#     Found existing installation: pillow 12.0.0━━━━━━━━━━━━━━━━  5/23 [pygments]
#     Uninstalling pillow-12.0.0:━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  5/23 [pygments]
#       Successfully uninstalled pillow-12.0.0━━━━━━━━━━━━━━━━━━  5/23 [pygments]
#   Attempting uninstall: packagingm━━━━━━━━━━━━━━━━━━━━━━━━━━━  7/23 [Pillow]
#     Found existing installation: packaging 24.2━━━━━━━━━━━━━━━  7/23 [Pillow]
#     Uninstalling packaging-24.2:━━━━━━━━━━━━━━━━━━━━━━━━━━  8/23 [packaging]
#       Successfully uninstalled packaging-24.2━━━━━━━━━━━━━━━━━  8/23 [packaging]
#   Attempting uninstall: numpy0m━━━━━━━━━━━━━━━━━━━━━━━━━━  8/23 [packaging]
#     Found existing installation: numpy 2.2.6━━━━━━━━━━━━━━━━━━  8/23 [packaging]
#     Uninstalling numpy-2.2.6:91m╸━━━━━━━━━━━━━━━━━━━━━━━━  9/23 [numpy]
#       Successfully uninstalled numpy-2.2.6━━━━━━━━━━━━━━━━━━━━  9/23 [numpy]
#   Attempting uninstall: mdurl91m╸━━━━━━━━━━━━━━━━━━━━━━━━  9/23 [numpy]
#     Found existing installation: mdurl 0.1.2━━━━━━━━━━━━━━━━━━  9/23 [numpy]
#     Uninstalling mdurl-0.1.2:━━━━━━━━━━━━━━━━━━━━━━━━  9/23 [numpy]
#       Successfully uninstalled mdurl-0.1.2━━━━━━━━━━━━━━━━━━━━  9/23 [numpy]
#   Attempting uninstall: kiwisolver╺━━━━━━━━━━━━━━━━━━━━━━ 10/23 [mdurl]
#     Found existing installation: kiwisolver 1.4.9━━━━━━━━━━━━━ 10/23 [mdurl]
#     Uninstalling kiwisolver-1.4.9:m━━━━━━━━━━━━━━━━━━━━━━ 10/23 [mdurl]
#       Successfully uninstalled kiwisolver-1.4.9━━━━━━━━━━━━━━━ 10/23 [mdurl]
#   Attempting uninstall: fonttools0m━━━━━━━━━━━━━━━━━━━━━━ 10/23 [mdurl]
#     Found existing installation: fonttools 4.61.1━━━━━━━━━━━━━ 10/23 [mdurl]
#     Uninstalling fonttools-4.61.1:m━━━━━━━━━━━━━━━━━━━━━━ 10/23 [mdurl]
#       Successfully uninstalled fonttools-4.61.1━━━━━━━━━━━━━━━ 10/23 [mdurl]
#   Attempting uninstall: cycler0m╸━━━━━━━━━━━━━━━━━━━ 12/23 [fonttools]
#     Found existing installation: cycler 0.12.1━━━━━━━━━━━━━━━━ 12/23 [fonttools]
#     Uninstalling cycler-0.12.1:1m╸━━━━━━━━━━━━━━━━━━━ 12/23 [fonttools]
#       Successfully uninstalled cycler-0.12.1━━━━━━━━━━━━━━━━━━ 12/23 [fonttools]
#   Attempting uninstall: yapf╸━━━━━━━━━━━━━━━━━━━ 12/23 [fonttools]
#     Found existing installation: yapf 0.43.0━━━━━━━━━━━━━━━━━━ 12/23 [fonttools]
#     Uninstalling yapf-0.43.0:╸━━━━━━━━━━━━━━━━━━━ 12/23 [fonttools]
#       Successfully uninstalled yapf-0.43.0m━━━━━━━━━━━━━━━━━━━ 12/23 [fonttools]
#   Attempting uninstall: python-dateutil0m╺━━━━━━━━━━━━━━━ 14/23 [yapf]]
#     Found existing installation: python-dateutil 2.9.0.post0━━ 14/23 [yapf]
#     Uninstalling python-dateutil-2.9.0.post0:0m━━━━━━━━━━━━━━━ 14/23 [yapf]
#       Successfully uninstalled python-dateutil-2.9.0.post0━━━━ 14/23 [yapf]
#   Attempting uninstall: opencv-python╺━━━━━━━━━━━━━━━ 14/23 [yapf]
#     Found existing installation: opencv-python 4.12.0.88━━━━━━ 14/23 [yapf]
#     Uninstalling opencv-python-4.12.0.88:m━━━━━━━━━━━━━━━ 14/23 [yapf]
#       Successfully uninstalled opencv-python-4.12.0.88━━━━━━━━ 14/23 [yapf]
#   Attempting uninstall: markdown-it-pym╸━━━━━━━━━━━━ 16/23 [opencv-python]
#     Found existing installation: markdown-it-py 4.0.0━━━━━━━━━ 16/23 [opencv-python]
#     Uninstalling markdown-it-py-4.0.0:1m╸━━━━━━━━━━━━ 16/23 [opencv-python]
#       Successfully uninstalled markdown-it-py-4.0.0━━━━━━━━━━━ 16/23 [opencv-python]
#   Attempting uninstall: contourpy━━━━╸━━━━━━━━━━ 17/23 [markdown-it-py]
#     Found existing installation: contourpy 1.3.3━━━━━━━━━━ 17/23 [markdown-it-py]
#     Uninstalling contourpy-1.3.3:╸━━━━━━━━━━ 17/23 [markdown-it-py]
#       Successfully uninstalled contourpy-1.3.3m━━━━━━━━━━ 17/23 [markdown-it-py]
#   Attempting uninstall: rich━━━━━╸━━━━━━━━━━ 17/23 [markdown-it-py]
#     Found existing installation: rich 13.4.2━━━━━━━━━━ 17/23 [markdown-it-py]
#     Uninstalling rich-13.4.2:━━━━╸━━━━━━━━━━ 17/23 [markdown-it-py]
#       Successfully uninstalled rich-13.4.2╸━━━━━━━━━━ 17/23 [markdown-it-py]
#   Attempting uninstall: matplotlib━━━━━━━╺━━━━━━ 19/23 [rich]it-py]
#     Found existing installation: matplotlib 3.10.8m━━━━━━ 19/23 [rich]
#     Uninstalling matplotlib-3.10.8:━━╺━━━━━━ 19/23 [rich]
#       Successfully uninstalled matplotlib-3.10.891m╸━━━━━ 20/23 [matplotlib]
#   Attempting uninstall: mmengine━━━━━━━━━━╸━━━━━ 20/23 [matplotlib]
#     Found existing installation: mmengine 0.10.7━━━━━ 20/23 [matplotlib]
#     Uninstalling mmengine-0.10.7:━━━━━╸━━━━━ 20/23 [matplotlib]
#       Successfully uninstalled mmengine-0.10.7m╸━━━━━ 20/23 [matplotlib]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23/23 [mmcv]2m22/23 [mmcv]ine]
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# openxlab 0.1.3 requires packaging~=24.0, but you have packaging 25.0 which is incompatible.
# openxlab 0.1.3 requires rich~=13.4.2, but you have rich 14.2.0 which is incompatible.
# openxlab 0.1.3 requires setuptools~=60.2.0, but you have setuptools 80.9.0 which is incompatible.
# Successfully installed Pillow-12.0.0 addict-2.4.0 contourpy-1.3.3 cycler-0.12.1 fonttools-4.61.1 kiwisolver-1.4.9 markdown-it-py-4.0.0 matplotlib-3.10.8 mdurl-0.1.2 mmcv-2.1.0 mmengine-0.10.7 numpy-2.2.6 opencv-python-4.12.0.88 packaging-25.0 platformdirs-4.5.1 pygments-2.19.2 pyparsing-3.3.1 python-dateutil-2.9.0.post0 pyyaml-6.0.3 rich-14.2.0 six-1.17.0 termcolor-3.2.0 yapf-0.43.0

# %%
import sys
sys.path.insert(0, '/home/miniforge3/lib/python3.12/site-packages')
import mmcv
print(mmcv.__version__, mmcv.__file__)
# Out:
# 2.1.0 /home/miniforge3/lib/python3.12/site-packages/mmcv/__init__.py

# %%
import mmseg

# %%
# Install PyTorch
# !conda install pytorch==1.12.0 torchvision==0.13.0 torchaudio==0.12.0 cudatoolkit=11.3 -c pytorch
! pip install torch torchvision --index-url https://download.pytorch.org/whl/cu126
# Install mim
# !pip install -U openmim
# Upgrade setuptools and pip for Python 3.12+ compatibility after openmim potentially downgrades them
# !pip install --upgrade setuptools pip
# Install mmengine
# !mim install mmengine
# Install MMCV
# !mim install 'mmcv >= 2.0.0rc4'
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu126
# Requirement already satisfied: torch in ./miniforge3/lib/python3.12/site-packages (2.9.1+cu126)
# Requirement already satisfied: torchvision in ./miniforge3/lib/python3.12/site-packages (0.24.1+cu126)
# Requirement already satisfied: filelock in ./miniforge3/lib/python3.12/site-packages (from torch) (3.14.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in ./miniforge3/lib/python3.12/site-packages (from torch) (4.15.0)
# Requirement already satisfied: setuptools in ./miniforge3/lib/python3.12/site-packages (from torch) (80.9.0)
# Requirement already satisfied: sympy>=1.13.3 in ./miniforge3/lib/python3.12/site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in ./miniforge3/lib/python3.12/site-packages (from torch) (3.6.1)
# Requirement already satisfied: jinja2 in ./miniforge3/lib/python3.12/site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in ./miniforge3/lib/python3.12/site-packages (from torch) (2025.12.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in ./miniforge3/lib/python3.12/site-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in ./miniforge3/lib/python3.12/site-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in ./miniforge3/lib/python3.12/site-packages (from torch) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in ./miniforge3/lib/python3.12/site-packages (from torch) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in ./miniforge3/lib/python3.12/site-packages (from torch) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in ./miniforge3/lib/python3.12/site-packages (from torch) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in ./miniforge3/lib/python3.12/site-packages (from torch) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in ./miniforge3/lib/python3.12/site-packages (from torch) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in ./miniforge3/lib/python3.12/site-packages (from torch) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in ./miniforge3/lib/python3.12/site-packages (from torch) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in ./miniforge3/lib/python3.12/site-packages (from torch) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in ./miniforge3/lib/python3.12/site-packages (from torch) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in ./miniforge3/lib/python3.12/site-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in ./miniforge3/lib/python3.12/site-packages (from torch) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in ./miniforge3/lib/python3.12/site-packages (from torch) (1.11.1.6)
# Requirement already satisfied: triton==3.5.1 in ./miniforge3/lib/python3.12/site-packages (from torch) (3.5.1)
# Requirement already satisfied: numpy in ./miniforge3/lib/python3.12/site-packages (from torchvision) (2.2.6)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in ./miniforge3/lib/python3.12/site-packages (from torchvision) (12.0.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in ./miniforge3/lib/python3.12/site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in ./miniforge3/lib/python3.12/site-packages (from jinja2->torch) (2.1.5)
# Requirement already satisfied: openmim in ./miniforge3/lib/python3.12/site-packages (0.3.9)
# Requirement already satisfied: Click in ./miniforge3/lib/python3.12/site-packages (from openmim) (8.3.1)
# Requirement already satisfied: colorama in ./miniforge3/lib/python3.12/site-packages (from openmim) (0.4.6)
# Requirement already satisfied: model-index in ./miniforge3/lib/python3.12/site-packages (from openmim) (0.1.11)
# Requirement already satisfied: opendatalab in ./miniforge3/lib/python3.12/site-packages (from openmim) (0.0.10)
# Requirement already satisfied: pandas in ./miniforge3/lib/python3.12/site-packages (from openmim) (2.3.3)
# Requirement already satisfied: pip>=19.3 in ./miniforge3/lib/python3.12/site-packages (from openmim) (25.3)
# Requirement already satisfied: requests in ./miniforge3/lib/python3.12/site-packages (from openmim) (2.28.2)
# Requirement already satisfied: rich in ./miniforge3/lib/python3.12/site-packages (from openmim) (13.4.2)
# Requirement already satisfied: tabulate in ./miniforge3/lib/python3.12/site-packages (from openmim) (0.9.0)
# Requirement already satisfied: pyyaml in ./miniforge3/lib/python3.12/site-packages (from model-index->openmim) (6.0.3)
# Requirement already satisfied: markdown in ./miniforge3/lib/python3.12/site-packages (from model-index->openmim) (3.10)
# Requirement already satisfied: ordered-set in ./miniforge3/lib/python3.12/site-packages (from model-index->openmim) (4.1.0)
# Requirement already satisfied: pycryptodome in ./miniforge3/lib/python3.12/site-packages (from opendatalab->openmim) (3.23.0)
# Requirement already satisfied: tqdm in ./miniforge3/lib/python3.12/site-packages (from opendatalab->openmim) (4.65.2)
# Requirement already satisfied: openxlab in ./miniforge3/lib/python3.12/site-packages (from opendatalab->openmim) (0.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./miniforge3/lib/python3.12/site-packages (from requests->openmim) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in ./miniforge3/lib/python3.12/site-packages (from requests->openmim) (3.11)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in ./miniforge3/lib/python3.12/site-packages (from requests->openmim) (1.26.20)
# Requirement already satisfied: certifi>=2017.4.17 in ./miniforge3/lib/python3.12/site-packages (from requests->openmim) (2025.11.12)
# Requirement already satisfied: filelock~=3.14.0 in ./miniforge3/lib/python3.12/site-packages (from openxlab->opendatalab->openmim) (3.14.0)
# Requirement already satisfied: oss2~=2.17.0 in ./miniforge3/lib/python3.12/site-packages (from openxlab->opendatalab->openmim) (2.17.0)
# Requirement already satisfied: packaging~=24.0 in ./miniforge3/lib/python3.12/site-packages (from openxlab->opendatalab->openmim) (24.2)
# Requirement already satisfied: pytz~=2023.3 in ./miniforge3/lib/python3.12/site-packages (from openxlab->opendatalab->openmim) (2023.4)
# Collecting setuptools~=60.2.0 (from openxlab->opendatalab->openmim)
#   Using cached setuptools-60.2.0-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: crcmod>=1.7 in ./miniforge3/lib/python3.12/site-packages (from oss2~=2.17.0->openxlab->opendatalab->openmim) (1.7)
# Requirement already satisfied: aliyun-python-sdk-kms>=2.4.1 in ./miniforge3/lib/python3.12/site-packages (from oss2~=2.17.0->openxlab->opendatalab->openmim) (2.16.5)
# Requirement already satisfied: aliyun-python-sdk-core>=2.13.12 in ./miniforge3/lib/python3.12/site-packages (from oss2~=2.17.0->openxlab->opendatalab->openmim) (2.16.0)
# Requirement already satisfied: six in ./miniforge3/lib/python3.12/site-packages (from oss2~=2.17.0->openxlab->opendatalab->openmim) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in ./miniforge3/lib/python3.12/site-packages (from rich->openmim) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in ./miniforge3/lib/python3.12/site-packages (from rich->openmim) (2.19.2)
# Requirement already satisfied: jmespath<1.0.0,>=0.9.3 in ./miniforge3/lib/python3.12/site-packages (from aliyun-python-sdk-core>=2.13.12->oss2~=2.17.0->openxlab->opendatalab->openmim) (0.10.0)
# Requirement already satisfied: cryptography>=3.0.0 in ./miniforge3/lib/python3.12/site-packages (from aliyun-python-sdk-core>=2.13.12->oss2~=2.17.0->openxlab->opendatalab->openmim) (46.0.3)
# Requirement already satisfied: cffi>=2.0.0 in ./miniforge3/lib/python3.12/site-packages (from cryptography>=3.0.0->aliyun-python-sdk-core>=2.13.12->oss2~=2.17.0->openxlab->opendatalab->openmim) (2.0.0)
# Requirement already satisfied: pycparser in ./miniforge3/lib/python3.12/site-packages (from cffi>=2.0.0->cryptography>=3.0.0->aliyun-python-sdk-core>=2.13.12->oss2~=2.17.0->openxlab->opendatalab->openmim) (2.22)
# Requirement already satisfied: mdurl~=0.1 in ./miniforge3/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich->openmim) (0.1.2)
# Requirement already satisfied: numpy>=1.26.0 in ./miniforge3/lib/python3.12/site-packages (from pandas->openmim) (2.2.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./miniforge3/lib/python3.12/site-packages (from pandas->openmim) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in ./miniforge3/lib/python3.12/site-packages (from pandas->openmim) (2025.3)
# Using cached setuptools-60.2.0-py3-none-any.whl (953 kB)
# Installing collected packages: setuptools
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 80.9.0
#     Uninstalling setuptools-80.9.0:
#       Successfully uninstalled setuptools-80.9.0
# Successfully installed setuptools-60.2.0
# Requirement already satisfied: setuptools in ./miniforge3/lib/python3.12/site-packages (60.2.0)
# Collecting setuptools
#   Using cached setuptools-80.9.0-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: pip in ./miniforge3/lib/python3.12/site-packages (25.3)
# Using cached setuptools-80.9.0-py3-none-any.whl (1.2 MB)
# Installing collected packages: setuptools
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 60.2.0
#     Uninstalling setuptools-60.2.0:
#       Successfully uninstalled setuptools-60.2.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# openxlab 0.1.3 requires setuptools~=60.2.0, but you have setuptools 80.9.0 which is incompatible.
# Successfully installed setuptools-80.9.0
# /home/miniforge3/lib/python3.12/site-packages/mim/commands/list.py:4: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# Looking in links: https://download.openmmlab.com/mmcv/dist/cu126/torch2.9.0/index.html
# Requirement already satisfied: mmengine in ./miniforge3/lib/python3.12/site-packages (0.10.7)
# Requirement already satisfied: addict in ./miniforge3/lib/python3.12/site-packages (from mmengine) (2.4.0)
# Requirement already satisfied: matplotlib in ./miniforge3/lib/python3.12/site-packages (from mmengine) (3.10.8)
# Requirement already satisfied: numpy in ./miniforge3/lib/python3.12/site-packages (from mmengine) (2.2.6)
# Requirement already satisfied: pyyaml in ./miniforge3/lib/python3.12/site-packages (from mmengine) (6.0.3)
# Requirement already satisfied: rich in ./miniforge3/lib/python3.12/site-packages (from mmengine) (13.4.2)
# Requirement already satisfied: termcolor in ./miniforge3/lib/python3.12/site-packages (from mmengine) (3.2.0)
# Requirement already satisfied: yapf in ./miniforge3/lib/python3.12/site-packages (from mmengine) (0.43.0)
# Requirement already satisfied: opencv-python>=3 in ./miniforge3/lib/python3.12/site-packages (from mmengine) (4.12.0.88)
# Requirement already satisfied: contourpy>=1.0.1 in ./miniforge3/lib/python3.12/site-packages (from matplotlib->mmengine) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in ./miniforge3/lib/python3.12/site-packages (from matplotlib->mmengine) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in ./miniforge3/lib/python3.12/site-packages (from matplotlib->mmengine) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./miniforge3/lib/python3.12/site-packages (from matplotlib->mmengine) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in ./miniforge3/lib/python3.12/site-packages (from matplotlib->mmengine) (24.2)
# Requirement already satisfied: pillow>=8 in ./miniforge3/lib/python3.12/site-packages (from matplotlib->mmengine) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in ./miniforge3/lib/python3.12/site-packages (from matplotlib->mmengine) (3.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in ./miniforge3/lib/python3.12/site-packages (from matplotlib->mmengine) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in ./miniforge3/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib->mmengine) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in ./miniforge3/lib/python3.12/site-packages (from rich->mmengine) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in ./miniforge3/lib/python3.12/site-packages (from rich->mmengine) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in ./miniforge3/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich->mmengine) (0.1.2)
# Requirement already satisfied: platformdirs>=3.5.1 in ./miniforge3/lib/python3.12/site-packages (from yapf->mmengine) (4.5.0)
# mim resources not found: /home/miniforge3/lib/python3.12/site-packages/mmseg/.mim, you can try to install the latest mmsegmentation.
# /home/miniforge3/lib/python3.12/site-packages/mim/commands/list.py:4: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# Looking in links: https://download.openmmlab.com/mmcv/dist/cu126/torch2.9.0/index.html
# Requirement already satisfied: mmcv>=2.0.0rc4 in ./miniforge3/lib/python3.12/site-packages (2.2.0)
# Requirement already satisfied: addict in ./miniforge3/lib/python3.12/site-packages (from mmcv>=2.0.0rc4) (2.4.0)
# Requirement already satisfied: mmengine>=0.3.0 in ./miniforge3/lib/python3.12/site-packages (from mmcv>=2.0.0rc4) (0.10.7)
# Requirement already satisfied: numpy in ./miniforge3/lib/python3.12/site-packages (from mmcv>=2.0.0rc4) (2.2.6)
# Requirement already satisfied: packaging in ./miniforge3/lib/python3.12/site-packages (from mmcv>=2.0.0rc4) (24.2)
# Requirement already satisfied: Pillow in ./miniforge3/lib/python3.12/site-packages (from mmcv>=2.0.0rc4) (12.0.0)
# Requirement already satisfied: pyyaml in ./miniforge3/lib/python3.12/site-packages (from mmcv>=2.0.0rc4) (6.0.3)
# Requirement already satisfied: yapf in ./miniforge3/lib/python3.12/site-packages (from mmcv>=2.0.0rc4) (0.43.0)
# Requirement already satisfied: opencv-python>=3 in ./miniforge3/lib/python3.12/site-packages (from mmcv>=2.0.0rc4) (4.12.0.88)
# Requirement already satisfied: matplotlib in ./miniforge3/lib/python3.12/site-packages (from mmengine>=0.3.0->mmcv>=2.0.0rc4) (3.10.8)
# Requirement already satisfied: rich in ./miniforge3/lib/python3.12/site-packages (from mmengine>=0.3.0->mmcv>=2.0.0rc4) (13.4.2)
# Requirement already satisfied: termcolor in ./miniforge3/lib/python3.12/site-packages (from mmengine>=0.3.0->mmcv>=2.0.0rc4) (3.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in ./miniforge3/lib/python3.12/site-packages (from matplotlib->mmengine>=0.3.0->mmcv>=2.0.0rc4) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in ./miniforge3/lib/python3.12/site-packages (from matplotlib->mmengine>=0.3.0->mmcv>=2.0.0rc4) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in ./miniforge3/lib/python3.12/site-packages (from matplotlib->mmengine>=0.3.0->mmcv>=2.0.0rc4) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./miniforge3/lib/python3.12/site-packages (from matplotlib->mmengine>=0.3.0->mmcv>=2.0.0rc4) (1.4.9)
# Requirement already satisfied: pyparsing>=3 in ./miniforge3/lib/python3.12/site-packages (from matplotlib->mmengine>=0.3.0->mmcv>=2.0.0rc4) (3.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in ./miniforge3/lib/python3.12/site-packages (from matplotlib->mmengine>=0.3.0->mmcv>=2.0.0rc4) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in ./miniforge3/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib->mmengine>=0.3.0->mmcv>=2.0.0rc4) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in ./miniforge3/lib/python3.12/site-packages (from rich->mmengine>=0.3.0->mmcv>=2.0.0rc4) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in ./miniforge3/lib/python3.12/site-packages (from rich->mmengine>=0.3.0->mmcv>=2.0.0rc4) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in ./miniforge3/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich->mmengine>=0.3.0->mmcv>=2.0.0rc4) (0.1.2)
# Requirement already satisfied: platformdirs>=3.5.1 in ./miniforge3/lib/python3.12/site-packages (from yapf->mmcv>=2.0.0rc4) (4.5.0)
# mim resources not found: /home/miniforge3/lib/python3.12/site-packages/mmseg/.mim, you can try to install the latest mmsegmentation.

# %%
! ls .
# Out:
# Miniforge3-Linux-x86_64.sh  mmsegmentation  sample_data

# %%
# !rm -rf mmsegmentation
# !git clone -b main https://github.com/open-mmlab/mmsegmentation.git
# %cd mmsegmentation
# !pip install -e .
# %cd /home
# Out:
# Cloning into 'mmsegmentation'...
# remote: Enumerating objects: 16493, done.
# remote: Total 16493 (delta 0), reused 0 (delta 0), pack-reused 16493 (from 1)
# Receiving objects: 100% (16493/16493), 44.24 MiB | 26.35 MiB/s, done.
# Resolving deltas: 100% (11495/11495), done.
# /home/mmsegmentation
# Obtaining file:///home/mmsegmentation
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Requirement already satisfied: matplotlib in /home/miniforge3/lib/python3.12/site-packages (from mmsegmentation==1.2.2) (3.10.8)
# Requirement already satisfied: numpy in /home/miniforge3/lib/python3.12/site-packages (from mmsegmentation==1.2.2) (2.2.6)
# Requirement already satisfied: packaging in /home/miniforge3/lib/python3.12/site-packages (from mmsegmentation==1.2.2) (24.2)
# Requirement already satisfied: prettytable in /home/miniforge3/lib/python3.12/site-packages (from mmsegmentation==1.2.2) (3.17.0)
# Requirement already satisfied: scipy in /home/miniforge3/lib/python3.12/site-packages (from mmsegmentation==1.2.2) (1.16.3)
# Requirement already satisfied: contourpy>=1.0.1 in /home/miniforge3/lib/python3.12/site-packages (from matplotlib->mmsegmentation==1.2.2) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /home/miniforge3/lib/python3.12/site-packages (from matplotlib->mmsegmentation==1.2.2) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/miniforge3/lib/python3.12/site-packages (from matplotlib->mmsegmentation==1.2.2) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/miniforge3/lib/python3.12/site-packages (from matplotlib->mmsegmentation==1.2.2) (1.4.9)
# Requirement already satisfied: pillow>=8 in /home/miniforge3/lib/python3.12/site-packages (from matplotlib->mmsegmentation==1.2.2) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in /home/miniforge3/lib/python3.12/site-packages (from matplotlib->mmsegmentation==1.2.2) (3.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in /home/miniforge3/lib/python3.12/site-packages (from matplotlib->mmsegmentation==1.2.2) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/miniforge3/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib->mmsegmentation==1.2.2) (1.17.0)
# Requirement already satisfied: wcwidth in /home/miniforge3/lib/python3.12/site-packages (from prettytable->mmsegmentation==1.2.2) (0.2.14)
# Building wheels for collected packages: mmsegmentation
#   Building editable for mmsegmentation (pyproject.toml) ... done
#   Created wheel for mmsegmentation: filename=mmsegmentation-1.2.2-0.editable-py3-none-any.whl size=13755 sha256=d15f19bca3ab982648573211a88738a0e640aa65bc4f97418aab2dd8e1d603bb
#   Stored in directory: /tmp/pip-ephem-wheel-cache-8sqo4_s6/wheels/b2/ea/c0/911c2218d0a6ef338eec9cad17620cc4c9e344e6b44c849815
# Successfully built mmsegmentation
# Installing collected packages: mmsegmentation
#   Attempting uninstall: mmsegmentation
#     Found existing installation: mmsegmentation 1.2.2
#     Uninstalling mmsegmentation-1.2.2:
#       Successfully uninstalled mmsegmentation-1.2.2
# Successfully installed mmsegmentation-1.2.2
# /home

# %%
# %cd /home
# Out:
# /home

# %%
# Out:
# /home/miniforge3/bin/python
# Python 3.12.12

# %%
! ls /home/miniforge3/lib/python3.12/site-packages
# Out:
# addict
# addict-2.4.0.dist-info
# aliyun_python_sdk_core-2.16.0.dist-info
# aliyun_python_sdk_kms-2.16.5.dist-info
# aliyunsdkcore
# aliyunsdkkms
# archspec
# archspec-0.2.5.dist-info
# boltons
# boltons-25.0.0.dist-info
# brotli-1.2.0.dist-info
# _brotli.cpython-312-x86_64-linux-gnu.so
# brotli.py
# certifi
# certifi-2025.11.12.dist-info
# cffi
# cffi-2.0.0.dist-info
# _cffi_backend.cpython-312-x86_64-linux-gnu.so
# charset_normalizer
# charset_normalizer-3.4.4.dist-info
# click
# click-8.3.1.dist-info
# colorama
# colorama-0.4.6.dist-info
# conda
# conda-25.11.0.dist-info
# conda_env
# conda_libmamba_solver
# conda_libmamba_solver-25.11.0.dist-info
# conda_package_handling
# conda_package_handling-2.4.0.dist-info
# conda_package_streaming
# conda_package_streaming-0.12.0.dist-info
# contourpy
# contourpy-1.3.3.dist-info
# crcmod
# crcmod-1.7.dist-info
# Crypto
# cryptography
# cryptography-46.0.3.dist-info
# cv2
# cycler
# cycler-0.12.1.dist-info
# dateutil
# distro
# distro-1.9.0.dist-info
# _distutils_hack
# distutils-precedence.pth
# __editable___mmsegmentation_1_2_2_finder.py
# __editable__.mmsegmentation-1.2.2.pth
# filelock
# filelock-3.14.0.dist-info
# fontTools
# fonttools-4.61.1.dist-info
# frozendict
# frozendict-2.4.7.dist-info
# fsspec
# fsspec-2025.12.0.dist-info
# functorch
# h2
# h2-4.3.0.dist-info
# hpack
# hpack-4.1.0.dist-info
# hyperframe
# hyperframe-6.1.0.dist-info
# idna
# idna-3.11.dist-info
# isympy.py
# jinja2
# jinja2-3.1.6.dist-info
# jmespath
# jmespath-0.10.0.dist-info
# jsonpatch-1.33.dist-info
# jsonpatch.py
# jsonpointer-3.0.0.dist-info
# jsonpointer.py
# kiwisolver
# kiwisolver-1.4.9.dist-info
# libmambapy
# libmambapy-2.4.0.dist-info
# markdown
# markdown-3.10.dist-info
# markdown_it
# markdown_it_py-4.0.0.dist-info
# markupsafe
# MarkupSafe-2.1.5.dist-info
# matplotlib
# matplotlib-3.10.8.dist-info
# mdurl
# mdurl-0.1.2.dist-info
# menuinst
# menuinst-2.4.1.dist-info
# mim
# mmcv
# mmcv-2.2.0.dist-info
# mmengine
# mmengine-0.10.7.dist-info
# mmsegmentation-1.2.2.dist-info
# modelindex
# model_index-0.1.11.dist-info
# mpl_toolkits
# mpmath
# mpmath-1.3.0.dist-info
# msgpack
# msgpack-1.1.2.dist-info
# networkx
# networkx-3.6.1.dist-info
# numpy
# numpy-2.2.6.dist-info
# numpy.libs
# nvidia
# nvidia_cublas_cu12-12.6.4.1.dist-info
# nvidia_cuda_cupti_cu12-12.6.80.dist-info
# nvidia_cuda_nvrtc_cu12-12.6.77.dist-info
# nvidia_cuda_runtime_cu12-12.6.77.dist-info
# nvidia_cudnn_cu12-9.10.2.21.dist-info
# nvidia_cufft_cu12-11.3.0.4.dist-info
# nvidia_cufile_cu12-1.11.1.6.dist-info
# nvidia_curand_cu12-10.3.7.77.dist-info
# nvidia_cusolver_cu12-11.7.1.2.dist-info
# nvidia_cusparse_cu12-12.5.4.2.dist-info
# nvidia_cusparselt_cu12-0.7.1.dist-info
# nvidia_nccl_cu12-2.27.5.dist-info
# nvidia_nvjitlink_cu12-12.6.85.dist-info
# nvidia_nvshmem_cu12-3.3.20.dist-info
# nvidia_nvtx_cu12-12.6.77.dist-info
# opencv_python-4.12.0.88.dist-info
# opencv_python.libs
# opendatalab
# opendatalab-0.0.10.dist-info
# openmim-0.3.9.dist-info
# openxlab
# openxlab-0.1.3.dist-info
# ordered_set
# ordered_set-4.1.0.dist-info
# oss2
# oss2-2.17.0.dist-info
# packaging
# packaging-24.2.dist-info
# pandas
# pandas-2.3.3.dist-info
# PIL
# pillow-12.0.0.dist-info
# pillow.libs
# pip
# pip-25.3.dist-info
# pkg_resources
# platformdirs
# platformdirs-4.5.0.dist-info
# pluggy
# pluggy-1.6.0.dist-info
# prettytable
# prettytable-3.17.0.dist-info
# __pycache__
# pycosat-0.6.6.dist-info
# pycosat.cpython-312-x86_64-linux-gnu.so
# pycparser
# pycparser-2.22.dist-info
# pycryptodome-3.23.0.dist-info
# pygments
# pygments-2.19.2.dist-info
# pylab.py
# pyparsing
# pyparsing-3.3.1.dist-info
# PySocks-1.7.1.dist-info
# python_dateutil-2.9.0.post0.dist-info
# pytz
# pytz-2023.4.dist-info
# pyyaml-6.0.3.dist-info
# README.txt
# requests
# requests-2.28.2.dist-info
# rich
# rich-13.4.2.dist-info
# ruamel
# ruamel_yaml-0.18.16.dist-info
# ruamel_yaml_clib-0.2.14.dist-info
# _ruamel_yaml.cpython-312-x86_64-linux-gnu.so
# scipy
# scipy-1.16.3.dist-info
# scipy.libs
# setuptools
# setuptools-80.9.0.dist-info
# six-1.17.0.dist-info
# six.py
# sockshandler.py
# socks.py
# sympy
# sympy-1.14.0.dist-info
# tabulate
# tabulate-0.9.0.dist-info
# termcolor
# termcolor-3.2.0.dist-info
# test_pycosat.py
# tests
# torch
# torch-2.9.1+cu126.dist-info
# torchgen
# torchvision
# torchvision-0.24.1+cu126.dist-info
# torchvision.libs
# tqdm
# tqdm-4.65.2.dist-info
# triton
# triton-3.5.1.dist-info
# truststore
# truststore-0.10.3.dist-info
# typing_extensions-4.15.0.dist-info
# typing_extensions.py
# tzdata
# tzdata-2025.3.dist-info
# urllib3
# urllib3-1.26.20.dist-info
# wcwidth
# wcwidth-0.2.14.dist-info
# wheel
# wheel-0.45.1.dist-info
# xontrib
# _yaml
# yaml
# yapf
# yapf-0.43.0.dist-info
# yapftests
# yapf_third_party
# zstandard
# zstandard-0.25.0-py3.12.egg-info

# %%
# Check if package is installed
# !pip show mmsegmentation

# Check if it's in editable mode
# !pip list | grep mmseg

# Try importing
import mmseg
print(mmseg.__version__)
print(mmseg.__file__)
# Out:
# Name: mmsegmentation
# Version: 1.2.2
# Summary: Open MMLab Semantic Segmentation Toolbox and Benchmark
# Home-page: https://github.com/open-mmlab/mmsegmentation
# Author: MMSegmentation Contributors
# Author-email: openmmlab@gmail.com
# License: Apache License 2.0
# Location: /home/miniforge3/lib/python3.12/site-packages
# Editable project location: /home/mmsegmentation
# Requires: matplotlib, numpy, packaging, prettytable, scipy
# Required-by:
# mmsegmentation           1.2.2        /home/mmsegmentation
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipython-input-2346966778.py in <cell line: 0>()
#       6
#       7 # Try importing
# ----> 8 import mmseg
#       9 print(mmseg.__version__)
#      10 print(mmseg.__file__)
#
# ModuleNotFoundError: No module named 'mmseg'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# !pip install openmim
! pip install --upgrade setuptools pip
# !mim install --upgrade "mmcv>=2.0.0rc4"
# Out:
# Collecting openmim
#   Using cached openmim-0.3.9-py2.py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: Click in /usr/local/lib/python3.12/dist-packages (from openmim) (8.3.1)
# Collecting colorama (from openmim)
#   Downloading colorama-0.4.6-py2.py3-none-any.whl.metadata (17 kB)
# Collecting model-index (from openmim)
#   Using cached model_index-0.1.11-py3-none-any.whl.metadata (3.9 kB)
# Collecting opendatalab (from openmim)
#   Using cached opendatalab-0.0.10-py3-none-any.whl.metadata (6.4 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from openmim) (2.2.2)
# Requirement already satisfied: pip>=19.3 in /usr/local/lib/python3.12/dist-packages (from openmim) (24.1.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from openmim) (2.32.4)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from openmim) (13.9.4)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.12/dist-packages (from openmim) (0.9.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from model-index->openmim) (6.0.3)
# Requirement already satisfied: markdown in /usr/local/lib/python3.12/dist-packages (from model-index->openmim) (3.10)
# Collecting ordered-set (from model-index->openmim)
#   Using cached ordered_set-4.1.0-py3-none-any.whl.metadata (5.3 kB)
# Collecting pycryptodome (from opendatalab->openmim)
#   Using cached pycryptodome-3.23.0-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.4 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from opendatalab->openmim) (4.67.1)
# Collecting openxlab (from opendatalab->openmim)
#   Using cached openxlab-0.1.3-py3-none-any.whl.metadata (3.8 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->openmim) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->openmim) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->openmim) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->openmim) (2025.11.12)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from pandas->openmim) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->openmim) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->openmim) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->openmim) (2025.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->openmim) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich->openmim) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->openmim) (0.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->openmim) (1.17.0)
# Collecting filelock~=3.14.0 (from openxlab->opendatalab->openmim)
#   Using cached filelock-3.14.0-py3-none-any.whl.metadata (2.8 kB)
# Collecting oss2~=2.17.0 (from openxlab->opendatalab->openmim)
#   Using cached oss2-2.17.0-py3-none-any.whl
# Collecting packaging~=24.0 (from openxlab->opendatalab->openmim)
#   Using cached packaging-24.2-py3-none-any.whl.metadata (3.2 kB)
# Collecting pytz>=2020.1 (from pandas->openmim)
#   Using cached pytz-2023.4-py2.py3-none-any.whl.metadata (22 kB)
# Collecting requests (from openmim)
#   Using cached requests-2.28.2-py3-none-any.whl.metadata (4.6 kB)
# Collecting rich (from openmim)
#   Using cached rich-13.4.2-py3-none-any.whl.metadata (18 kB)
# Collecting setuptools~=60.2.0 (from openxlab->opendatalab->openmim)
#   Using cached setuptools-60.2.0-py3-none-any.whl.metadata (5.1 kB)
# Collecting tqdm (from opendatalab->openmim)
#   Using cached tqdm-4.65.2-py3-none-any.whl.metadata (56 kB)
# Collecting urllib3<1.27,>=1.21.1 (from requests->openmim)
#   Using cached urllib3-1.26.20-py2.py3-none-any.whl.metadata (50 kB)
# Collecting crcmod>=1.7 (from oss2~=2.17.0->openxlab->opendatalab->openmim)
#   Using cached crcmod-1.7-cp312-cp312-linux_x86_64.whl
# Collecting aliyun-python-sdk-kms>=2.4.1 (from oss2~=2.17.0->openxlab->opendatalab->openmim)
#   Using cached aliyun_python_sdk_kms-2.16.5-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting aliyun-python-sdk-core>=2.13.12 (from oss2~=2.17.0->openxlab->opendatalab->openmim)
#   Using cached aliyun_python_sdk_core-2.16.0-py3-none-any.whl
# Collecting jmespath<1.0.0,>=0.9.3 (from aliyun-python-sdk-core>=2.13.12->oss2~=2.17.0->openxlab->opendatalab->openmim)
#   Using cached jmespath-0.10.0-py2.py3-none-any.whl.metadata (8.0 kB)
# Requirement already satisfied: cryptography>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from aliyun-python-sdk-core>=2.13.12->oss2~=2.17.0->openxlab->opendatalab->openmim) (43.0.3)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.12/dist-packages (from cryptography>=3.0.0->aliyun-python-sdk-core>=2.13.12->oss2~=2.17.0->openxlab->opendatalab->openmim) (2.0.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.12->cryptography>=3.0.0->aliyun-python-sdk-core>=2.13.12->oss2~=2.17.0->openxlab->opendatalab->openmim) (2.23)
# Using cached openmim-0.3.9-py2.py3-none-any.whl (52 kB)
# Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Using cached model_index-0.1.11-py3-none-any.whl (34 kB)
# Using cached opendatalab-0.0.10-py3-none-any.whl (29 kB)
# Using cached openxlab-0.1.3-py3-none-any.whl (314 kB)
# Using cached requests-2.28.2-py3-none-any.whl (62 kB)
# Using cached rich-13.4.2-py3-none-any.whl (239 kB)
# Using cached pytz-2023.4-py2.py3-none-any.whl (506 kB)
# Using cached tqdm-4.65.2-py3-none-any.whl (77 kB)
# Using cached urllib3-1.26.20-py2.py3-none-any.whl (144 kB)
# Using cached ordered_set-4.1.0-py3-none-any.whl (7.6 kB)
# Using cached pycryptodome-3.23.0-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.3 MB)
# Using cached filelock-3.14.0-py3-none-any.whl (12 kB)
# Using cached packaging-24.2-py3-none-any.whl (65 kB)
# Using cached setuptools-60.2.0-py3-none-any.whl (953 kB)
# Using cached aliyun_python_sdk_kms-2.16.5-py2.py3-none-any.whl (99 kB)
# Using cached jmespath-0.10.0-py2.py3-none-any.whl (24 kB)
# Installing collected packages: pytz, crcmod, urllib3, tqdm, setuptools, pycryptodome, packaging, ordered-set, jmespath, filelock, colorama, rich, requests, model-index, aliyun-python-sdk-core, aliyun-python-sdk-kms, oss2, openxlab, opendatalab, openmim
#   Attempting uninstall: pytz
#     Found existing installation: pytz 2025.2
#     Uninstalling pytz-2025.2:
#       Successfully uninstalled pytz-2025.2
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.5.0
#     Uninstalling urllib3-2.5.0:
#       Successfully uninstalled urllib3-2.5.0
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.67.1
#     Uninstalling tqdm-4.67.1:
#       Successfully uninstalled tqdm-4.67.1
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 75.2.0
#     Uninstalling setuptools-75.2.0:
#       Successfully uninstalled setuptools-75.2.0
#   Attempting uninstall: packaging
#     Found existing installation: packaging 25.0
#     Uninstalling packaging-25.0:
#       Successfully uninstalled packaging-25.0
#   Attempting uninstall: filelock
#     Found existing installation: filelock 3.20.0
#     Uninstalling filelock-3.20.0:
#       Successfully uninstalled filelock-3.20.0
#   Attempting uninstall: rich
#     Found existing installation: rich 13.9.4
#     Uninstalling rich-13.9.4:
#       Successfully uninstalled rich-13.9.4
#   Attempting uninstall: requests
#     Found existing installation: requests 2.32.4
#     Uninstalling requests-2.32.4:
#       Successfully uninstalled requests-2.32.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython 7.34.0 requires jedi>=0.16, which is not installed.
# google-colab 1.0.0 requires requests==2.32.4, but you have requests 2.28.2 which is incompatible.
# google-adk 1.21.0 requires requests<3.0.0,>=2.32.4, but you have requests 2.28.2 which is incompatible.
# sphinx 8.2.3 requires requests>=2.30.0, but you have requests 2.28.2 which is incompatible.
# datasets 4.0.0 requires requests>=2.32.2, but you have requests 2.28.2 which is incompatible.
# datasets 4.0.0 requires tqdm>=4.66.3, but you have tqdm 4.65.2 which is incompatible.
# spopt 0.7.0 requires tqdm>=4.66.0, but you have tqdm 4.65.2 which is incompatible.
# yfinance 0.2.66 requires requests>=2.31, but you have requests 2.28.2 which is incompatible.
# pytensor 2.35.1 requires filelock>=3.15, but you have filelock 3.14.0 which is incompatible.
# pymc 5.26.1 requires rich>=13.7.1, but you have rich 13.4.2 which is incompatible.
# dataproc-spark-connect 1.0.1 requires tqdm>=4.67, but you have tqdm 4.65.2 which is incompatible.
# Successfully installed aliyun-python-sdk-core-2.16.0 aliyun-python-sdk-kms-2.16.5 colorama-0.4.6 crcmod-1.7 filelock-3.14.0 jmespath-0.10.0 model-index-0.1.11 opendatalab-0.0.10 openmim-0.3.9 openxlab-0.1.3 ordered-set-4.1.0 oss2-2.17.0 packaging-24.2 pycryptodome-3.23.0 pytz-2023.4 requests-2.28.2 rich-13.4.2 setuptools-60.2.0 tqdm-4.65.2 urllib3-1.26.20
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (60.2.0)
# Collecting setuptools
#   Using cached setuptools-80.9.0-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: pip in /usr/local/lib/python3.12/dist-packages (24.1.2)
# Collecting pip
#   Downloading pip-25.3-py3-none-any.whl.metadata (4.7 kB)
# Using cached setuptools-80.9.0-py3-none-any.whl (1.2 MB)
# Downloading pip-25.3-py3-none-any.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 35.4 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: setuptools, pip
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 60.2.0
#     Uninstalling setuptools-60.2.0:
#       Successfully uninstalled setuptools-60.2.0
#   Attempting uninstall: pip
#     Found existing installation: pip 24.1.2
#     Uninstalling pip-24.1.2:
#       Successfully uninstalled pip-24.1.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython 7.34.0 requires jedi>=0.16, which is not installed.
# openxlab 0.1.3 requires setuptools~=60.2.0, but you have setuptools 80.9.0 which is incompatible.
# pytensor 2.35.1 requires filelock>=3.15, but you have filelock 3.14.0 which is incompatible.
# pymc 5.26.1 requires rich>=13.7.1, but you have rich 13.4.2 which is incompatible.
# Successfully installed pip-25.3 setuptools-80.9.0
# /usr/local/lib/python3.12/dist-packages/mim/commands/list.py:4: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# Looking in links: https://download.openmmlab.com/mmcv/dist/cu126/torch2.9.0/index.html
# Collecting mmcv
#   Using cached mmcv-2.2.0-py2.py3-none-any.whl
# Collecting addict (from mmcv)
#   Using cached addict-2.4.0-py3-none-any.whl.metadata (1.0 kB)
# Collecting mmengine>=0.3.0 (from mmcv)
#   Using cached mmengine-0.10.7-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from mmcv) (2.0.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from mmcv) (24.2)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.12/dist-packages (from mmcv) (11.3.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from mmcv) (6.0.3)
# Collecting yapf (from mmcv)
#   Using cached yapf-0.43.0-py3-none-any.whl.metadata (46 kB)
# Requirement already satisfied: opencv-python>=3 in /usr/local/lib/python3.12/dist-packages (from mmcv) (4.12.0.88)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from mmengine>=0.3.0->mmcv) (3.10.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from mmengine>=0.3.0->mmcv) (13.4.2)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.12/dist-packages (from mmengine>=0.3.0->mmcv) (3.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mmengine>=0.3.0->mmcv) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mmengine>=0.3.0->mmcv) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mmengine>=0.3.0->mmcv) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mmengine>=0.3.0->mmcv) (1.4.9)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mmengine>=0.3.0->mmcv) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mmengine>=0.3.0->mmcv) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->mmengine>=0.3.0->mmcv) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->mmengine>=0.3.0->mmcv) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich->mmengine>=0.3.0->mmcv) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->mmengine>=0.3.0->mmcv) (0.1.2)
# Requirement already satisfied: platformdirs>=3.5.1 in /usr/local/lib/python3.12/dist-packages (from yapf->mmcv) (4.5.1)
# Using cached mmengine-0.10.7-py3-none-any.whl (452 kB)
# Using cached addict-2.4.0-py3-none-any.whl (3.8 kB)
# Using cached yapf-0.43.0-py3-none-any.whl (256 kB)
# Installing collected packages: addict, yapf, mmengine, mmcv
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4/4 [mmcv]3/4 [mmcv]ine]
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# mmsegmentation 1.2.2 requires mmcv<2.2.0,>=2.0.0rc4; extra == "mim", but you have mmcv 2.2.0 which is incompatible.
# Successfully installed addict-2.4.0 mmcv-2.2.0 mmengine-0.10.7 yapf-0.43.0

# %%
# !mim install --upgrade "mmcv>=2.0.0rc4"
# Out:
# /usr/local/lib/python3.12/dist-packages/mim/commands/list.py:4: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# Looking in links: https://download.openmmlab.com/mmcv/dist/cu126/torch2.9.0/index.html
# Requirement already satisfied: mmcv>=2.0.0rc4 in /usr/local/lib/python3.12/dist-packages (2.2.0)
# Requirement already satisfied: addict in /usr/local/lib/python3.12/dist-packages (from mmcv>=2.0.0rc4) (2.4.0)
# Requirement already satisfied: mmengine>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from mmcv>=2.0.0rc4) (0.10.7)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from mmcv>=2.0.0rc4) (2.0.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from mmcv>=2.0.0rc4) (24.2)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.12/dist-packages (from mmcv>=2.0.0rc4) (11.3.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from mmcv>=2.0.0rc4) (6.0.3)
# Requirement already satisfied: yapf in /usr/local/lib/python3.12/dist-packages (from mmcv>=2.0.0rc4) (0.43.0)
# Requirement already satisfied: opencv-python>=3 in /usr/local/lib/python3.12/dist-packages (from mmcv>=2.0.0rc4) (4.12.0.88)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from mmengine>=0.3.0->mmcv>=2.0.0rc4) (3.10.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from mmengine>=0.3.0->mmcv>=2.0.0rc4) (13.4.2)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.12/dist-packages (from mmengine>=0.3.0->mmcv>=2.0.0rc4) (3.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mmengine>=0.3.0->mmcv>=2.0.0rc4) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mmengine>=0.3.0->mmcv>=2.0.0rc4) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mmengine>=0.3.0->mmcv>=2.0.0rc4) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mmengine>=0.3.0->mmcv>=2.0.0rc4) (1.4.9)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mmengine>=0.3.0->mmcv>=2.0.0rc4) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mmengine>=0.3.0->mmcv>=2.0.0rc4) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->mmengine>=0.3.0->mmcv>=2.0.0rc4) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->mmengine>=0.3.0->mmcv>=2.0.0rc4) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich->mmengine>=0.3.0->mmcv>=2.0.0rc4) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->mmengine>=0.3.0->mmcv>=2.0.0rc4) (0.1.2)
# Requirement already satisfied: platformdirs>=3.5.1 in /usr/local/lib/python3.12/dist-packages (from yapf->mmcv>=2.0.0rc4) (4.5.1)

# %%
# !pip uninstall mmsegmentation -y
# !pip install mmsegmentation
# Out:
# Found existing installation: mmsegmentation 1.2.2
# Uninstalling mmsegmentation-1.2.2:
#   Successfully uninstalled mmsegmentation-1.2.2
# Collecting mmsegmentation
#   Using cached mmsegmentation-1.2.2-py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from mmsegmentation) (3.10.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from mmsegmentation) (2.0.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from mmsegmentation) (24.2)
# Requirement already satisfied: prettytable in /usr/local/lib/python3.12/dist-packages (from mmsegmentation) (3.17.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from mmsegmentation) (1.16.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mmsegmentation) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mmsegmentation) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mmsegmentation) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mmsegmentation) (1.4.9)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mmsegmentation) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mmsegmentation) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mmsegmentation) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->mmsegmentation) (1.17.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from prettytable->mmsegmentation) (0.2.14)
# Using cached mmsegmentation-1.2.2-py3-none-any.whl (2.4 MB)
# Installing collected packages: mmsegmentation
# Successfully installed mmsegmentation-1.2.2

# %%
# Check PyTorch installation
import torch, torchvision
print(torch.__version__, torch.cuda.is_available())

# Check MMSegmentation installation
import mmseg as mmseg
print(mmseg.__version__)
# Out:
# 2.9.0+cu126 True
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# /tmp/ipython-input-410614514.py in <cell line: 0>()
#       4
#       5 # Check MMSegmentation installation
# ----> 6 import mmseg as mmseg
#       7 print(mmseg.__version__)
#
# /home/miniforge3/lib/python3.12/site-packages/mmseg/__init__.py in <module>
#      59
#      60
# ---> 61 assert (mmcv_min_version <= mmcv_version < mmcv_max_version), \
#      62     f'MMCV=={mmcv.__version__} is used but incompatible. ' \
#      63     f'Please install mmcv>=2.0.0rc4.'
#
# AssertionError: MMCV==2.2.0 is used but incompatible. Please install mmcv>=2.0.0rc4.

# %%
# !pip install mmcv==2.0.0rc4
# Out:
# Collecting mmcv==2.0.0rc4
#   Downloading mmcv-2.0.0rc4.tar.gz (436 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: addict in /usr/local/lib/python3.12/dist-packages (from mmcv==2.0.0rc4) (2.4.0)
# Requirement already satisfied: mmengine>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from mmcv==2.0.0rc4) (0.10.7)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from mmcv==2.0.0rc4) (2.0.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from mmcv==2.0.0rc4) (24.2)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.12/dist-packages (from mmcv==2.0.0rc4) (11.3.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from mmcv==2.0.0rc4) (6.0.3)
# Requirement already satisfied: yapf in /usr/local/lib/python3.12/dist-packages (from mmcv==2.0.0rc4) (0.43.0)
# Requirement already satisfied: opencv-python>=3 in /usr/local/lib/python3.12/dist-packages (from mmcv==2.0.0rc4) (4.12.0.88)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from mmengine>=0.2.0->mmcv==2.0.0rc4) (3.10.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from mmengine>=0.2.0->mmcv==2.0.0rc4) (13.4.2)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.12/dist-packages (from mmengine>=0.2.0->mmcv==2.0.0rc4) (3.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mmengine>=0.2.0->mmcv==2.0.0rc4) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mmengine>=0.2.0->mmcv==2.0.0rc4) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mmengine>=0.2.0->mmcv==2.0.0rc4) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mmengine>=0.2.0->mmcv==2.0.0rc4) (1.4.9)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mmengine>=0.2.0->mmcv==2.0.0rc4) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mmengine>=0.2.0->mmcv==2.0.0rc4) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->mmengine>=0.2.0->mmcv==2.0.0rc4) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->mmengine>=0.2.0->mmcv==2.0.0rc4) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich->mmengine>=0.2.0->mmcv==2.0.0rc4) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->mmengine>=0.2.0->mmcv==2.0.0rc4) (0.1.2)
# Requirement already satisfied: platformdirs>=3.5.1 in /usr/local/lib/python3.12/dist-packages (from yapf->mmcv==2.0.0rc4) (4.5.1)
# Building wheels for collected packages: mmcv
#   Building wheel for mmcv (pyproject.toml) ... done
#   Created wheel for mmcv: filename=mmcv-2.0.0rc4-py2.py3-none-any.whl size=677373 sha256=dc6b0be299c55710320bc3ffee8579acf85d0591d350c85f14971878c9f355ce
#   Stored in directory: /root/.cache/pip/wheels/64/07/69/e99da7ee483c1cf2be156b9d334ac24f866ddd28c514795c69
# Successfully built mmcv
# Installing collected packages: mmcv
#   Attempting uninstall: mmcv
#     Found existing installation: mmcv 2.1.0
#     Uninstalling mmcv-2.1.0:
#       Successfully uninstalled mmcv-2.1.0
# Successfully installed mmcv-2.0.0rc4

# %% [markdown]
# ## Finetune a semantic segmentation model on a new dataset
#
# To finetune on a customized dataset, the following steps are necessary.
# 1. Add a new dataset class.
# 2. Create a config file accordingly.
# 3. Perform training and evaluation.

# %% [markdown]
# ### Add a new dataset
#
# Datasets in MMSegmentation require image and semantic segmentation maps to be placed in folders with the same prefix. To support a new dataset, we may need to modify the original file structure.
#
# In this tutorial, we give an example of converting the dataset. You may refer to [docs](https://github.com/open-mmlab/mmsegmentation/blob/master/docs/en/tutorials/customize_datasets.md#customize-datasets-by-reorganizing-data) for details about dataset reorganization.
#
# We use [Stanford Background Dataset](http://dags.stanford.edu/projects/scenedataset.html) as an example. The dataset contains 715 images chosen from existing public datasets [LabelMe](http://labelme.csail.mit.edu), [MSRC](http://research.microsoft.com/en-us/projects/objectclassrecognition), [PASCAL VOC](http://pascallin.ecs.soton.ac.uk/challenges/VOC) and [Geometric Context](http://www.cs.illinois.edu/homes/dhoiem/). Images from these datasets are mainly outdoor scenes, each containing approximately 320-by-240 pixels.
# In this tutorial, we use the region annotations as labels. There are 8 classes in total, i.e. sky, tree, road, grass, water, building, mountain, and foreground object.

# %%
# download and unzip
# !wget http://dags.stanford.edu/data/iccv09Data.tar.gz -O stanford_background.tar.gz
# !tar xf stanford_background.tar.gz

# %%
# Let's take a look at the dataset
import mmcv
import mmengine
import matplotlib.pyplot as plt


img = mmcv.imread('iccv09Data/images/6000124.jpg')
plt.figure(figsize=(8, 6))
plt.imshow(mmcv.bgr2rgb(img))
plt.show()

# %% [markdown]
# We need to convert the annotation into semantic map format as an image.

# %%
# define dataset root and directory for images and annotations
data_root = 'iccv09Data'
img_dir = 'images'
ann_dir = 'labels'
# define class and palette for better visualization
classes = ('sky', 'tree', 'road', 'grass', 'water', 'bldg', 'mntn', 'fg obj')
palette = [[128, 128, 128], [129, 127, 38], [120, 69, 125], [53, 125, 34],
           [0, 11, 123], [118, 20, 12], [122, 81, 25], [241, 134, 51]]

# %%
import os.path as osp
import numpy as np
from PIL import Image

# convert dataset annotation to semantic segmentation map
for file in mmengine.scandir(osp.join(data_root, ann_dir), suffix='.regions.txt'):
  seg_map = np.loadtxt(osp.join(data_root, ann_dir, file)).astype(np.uint8)
  seg_img = Image.fromarray(seg_map).convert('P')
  seg_img.putpalette(np.array(palette, dtype=np.uint8))
  seg_img.save(osp.join(data_root, ann_dir, file.replace('.regions.txt',
                                                         '.png')))

# %%
# Let's take a look at the segmentation map we got
import matplotlib.patches as mpatches
img = Image.open('iccv09Data/labels/6000124.png')
plt.figure(figsize=(8, 6))
im = plt.imshow(np.array(img.convert('RGB')))

# create a patch (proxy artist) for every color
patches = [mpatches.Patch(color=np.array(palette[i])/255.,
                          label=classes[i]) for i in range(8)]
# put those patched as legend-handles into the legend
plt.legend(handles=patches, bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.,
           fontsize='large')

plt.show()

# %%
# split train/val set randomly
split_dir = 'splits'
mmengine.mkdir_or_exist(osp.join(data_root, split_dir))
filename_list = [osp.splitext(filename)[0] for filename in mmengine.scandir(
    osp.join(data_root, ann_dir), suffix='.png')]
with open(osp.join(data_root, split_dir, 'train.txt'), 'w') as f:
  # select first 4/5 as train set
  train_length = int(len(filename_list)*4/5)
  f.writelines(line + '\n' for line in filename_list[:train_length])
with open(osp.join(data_root, split_dir, 'val.txt'), 'w') as f:
  # select last 1/5 as train set
  f.writelines(line + '\n' for line in filename_list[train_length:])

# %% [markdown]
# After downloading the data, we need to implement `load_annotations` function in the new dataset class `StanfordBackgroundDataset`.

# %%
from mmseg.registry import DATASETS
from mmseg.datasets import BaseSegDataset


@DATASETS.register_module()
class StanfordBackgroundDataset(BaseSegDataset):
  METAINFO = dict(classes = classes, palette = palette)
  def __init__(self, **kwargs):
    super().__init__(img_suffix='.jpg', seg_map_suffix='.png', **kwargs)

# %% [markdown]
# ### Create a config file
# In the next step, we need to modify the config for the training. To accelerate the process, we finetune the model from trained weights.

# %%
# Download config and checkpoint files
# !mim download mmsegmentation --config pspnet_r50-d8_4xb2-40k_cityscapes-512x1024 --dest .

# %%
from mmengine import Config
cfg = Config.fromfile('configs/pspnet/pspnet_r50-d8_4xb2-40k_cityscapes-512x1024.py')
print(f'Config:\n{cfg.pretty_text}')

# %% [markdown]
# Since the given config is used to train PSPNet on the cityscapes dataset, we need to modify it accordingly for our new dataset.

# %%
# Since we use only one GPU, BN is used instead of SyncBN
cfg.norm_cfg = dict(type='BN', requires_grad=True)
cfg.crop_size = (256, 256)
cfg.model.data_preprocessor.size = cfg.crop_size
cfg.model.backbone.norm_cfg = cfg.norm_cfg
cfg.model.decode_head.norm_cfg = cfg.norm_cfg
cfg.model.auxiliary_head.norm_cfg = cfg.norm_cfg
# modify num classes of the model in decode/auxiliary head
cfg.model.decode_head.num_classes = 8
cfg.model.auxiliary_head.num_classes = 8

# Modify dataset type and path
cfg.dataset_type = 'StanfordBackgroundDataset'
cfg.data_root = data_root

cfg.train_dataloader.batch_size = 8

cfg.train_pipeline = [
    dict(type='LoadImageFromFile'),
    dict(type='LoadAnnotations'),
    dict(type='RandomResize', scale=(320, 240), ratio_range=(0.5, 2.0), keep_ratio=True),
    dict(type='RandomCrop', crop_size=cfg.crop_size, cat_max_ratio=0.75),
    dict(type='RandomFlip', prob=0.5),
    dict(type='PackSegInputs')
]

cfg.test_pipeline = [
    dict(type='LoadImageFromFile'),
    dict(type='Resize', scale=(320, 240), keep_ratio=True),
    # add loading annotation after ``Resize`` because ground truth
    # does not need to do resize data transform
    dict(type='LoadAnnotations'),
    dict(type='PackSegInputs')
]


cfg.train_dataloader.dataset.type = cfg.dataset_type
cfg.train_dataloader.dataset.data_root = cfg.data_root
cfg.train_dataloader.dataset.data_prefix = dict(img_path=img_dir, seg_map_path=ann_dir)
cfg.train_dataloader.dataset.pipeline = cfg.train_pipeline
cfg.train_dataloader.dataset.ann_file = 'splits/train.txt'

cfg.val_dataloader.dataset.type = cfg.dataset_type
cfg.val_dataloader.dataset.data_root = cfg.data_root
cfg.val_dataloader.dataset.data_prefix = dict(img_path=img_dir, seg_map_path=ann_dir)
cfg.val_dataloader.dataset.pipeline = cfg.test_pipeline
cfg.val_dataloader.dataset.ann_file = 'splits/val.txt'

cfg.test_dataloader = cfg.val_dataloader


# Load the pretrained weights
cfg.load_from = 'pspnet_r50-d8_512x1024_40k_cityscapes_20200605_003338-2966598c.pth'

# Set up working dir to save files and logs.
cfg.work_dir = './work_dirs/tutorial'

cfg.train_cfg.max_iters = 200
cfg.train_cfg.val_interval = 200
cfg.default_hooks.logger.interval = 10
cfg.default_hooks.checkpoint.interval = 200

# Set seed to facilitate reproducing the result
cfg['randomness'] = dict(seed=0)

# Let's have a look at the final config used for training
print(f'Config:\n{cfg.pretty_text}')

# %% [markdown]
# ### Train and Evaluation

# %%
from mmengine.runner import Runner

runner = Runner.from_cfg(cfg)

# %%
# start training
runner.train()

# %% [markdown]
# Inference with trained model

# %%
from mmseg.apis import init_model, inference_model, show_result_pyplot

# Init the model from the config and the checkpoint
checkpoint_path = './work_dirs/tutorial/iter_200.pth'
model = init_model(cfg, checkpoint_path, 'cuda:0')

img = mmcv.imread('iccv09Data/images/6000124.jpg')
result = inference_model(model, img)
plt.figure(figsize=(8, 6))
vis_result = show_result_pyplot(model, img, result)
plt.imshow(mmcv.bgr2rgb(vis_result))
